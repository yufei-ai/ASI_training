# %%
# %matplotlib inline
import matplotlib as plt

colors = ['#0F87BA','#AC3048','#3AD4BD','#FFFF00'] # 3 brand colors plus a fourth (yellow added by Gabi)
darkColor = '#22333E' # brand color - dark
fsize = 12

plt.rc('font', **{'family' : 'Proxima Nova Light', # brand font -- sometimes I need to run code twice for the font to be found
        #'weight' : 'bold',
        'size'   : fsize})
lwidth = 1
#plt.rc('text',**{'color':'#AC3048'})
plt.rc('axes',**{'labelcolor':darkColor,'edgecolor':darkColor})
plt.rc('xtick',**{'color':darkColor})
plt.rc('ytick',**{'color':darkColor})

plt.rcParams["figure.figsize"] = (14,8)

axislabelsize = 20

import matplotlib.pyplot as plt
from pandas import *
from numpy.random import *
ts = Series(randn(1000), index=date_range('1/1/2000', periods=1000))

ts = 123+ts.cumsum()

ts.plot(color=colors[0], label='ABC.L',lw=lwidth); 

leg=plt.legend(prop={'size':fsize});
for idx, text in enumerate(leg.get_texts()):
    plt.setp(text, color = colors[idx])
plt.ylabel('Stock price',size=axislabelsize )
plt.xlabel('Date',size = axislabelsize )
