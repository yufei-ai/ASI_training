# %% [markdown]
# # MongoDB
#
# [MongoDB](http://www.mongodb.org/) is a widely used document-oriented NoSQL database. It's especially good for operating on large amounts of data and data that needs to be used by many users simultaneously, and so is used by large websites such as Craigslist, eBay, Foursquare, and LinkedIn.
#
# The purpose of this tutorial is to show you the basics of working with MongoDB. We'll cover how to insert documents into a MongoDB database and how to get lists of documents back from the database that match a particular set of criteria. This is barely scratching the surface of MongoDB! By the end of this session you'll have enough literacy in how MongoDB works to explore its more advanced features on your own.
#
# ## Why use a database?
#
# So what exactly is a database, and why might we need one? For our purpose, we can define a "database" as a piece of software whose main purpose is to make it possible for us to store data somewhere, then later retrieve it, usually in a way that pays attention to the structure of the data itself. There are several reasons we might want to put data into a database:
#
# * *Persistence*: we download data, process it into a form that we like, draw conclusions from it...and then it disappears forever, once we close the notebook. To get that data again, we have to download and process it again, from scratch. This is fine for small amounts of data, but with larger amounts it can be very time consuming. Having a database allows us to store our data in a way that persists from one notebook session to the next.
#
# * *Sharing*: another problem with downloading and processing data on demand is that it's difficult for us to share the result of our data processing with other data scientists. The data exists in our Jupyter notebook and nowhere else--there's no easy way to let someone else access it. A database like MongoDB, on the other hand, can be used by many people simultaneously. It's also easy to create a _dump_ of a MongoDB database and send it to a colleague, who can then reconstruct the data on their own server very easily.
#
# * *Performance*: many databases, like MongoDB, boast features (like indexing, aggregation, and map-reduce) that can make accessing and processing data very fast, faster than we can do in Python.
#
# ## Architecture
#
# MongoDB is client-server software, which means that the software itself runs on a server somewhere, and various clients on other computers can access it. The clients each talk to the server over the network, with a particular protocol unique to MongoDB. Most databases including PostgreSQL and MySQL work like this, but there are some exceptions, like SQLite, which work with files stored locally on your machine.
#
# We're going to write our client software in a Jupyter Notebook, using a library called `pymongo`. The `pymongo` library gives us an easy way to write Python code that opens a network connection to the server, sends it commands using the MongoDB protocol, and interprets the results that come back.
#
# The `pymongo` library can be installed on a SherlockML instances using `conda` with the following command:
#
#     $ conda install -y pymongo
#
# It can also be installed elsewhere with `pip` with the following command:
#
#     $ pip install pymongo
#
# You should generally favour `conda` over `pip` for installing database drivers, as they often have dependencies on shared libraries written in C. In this workshop, the database server (MongoDB itself) and the client software (the Python code running in your Jupyter notebook) both live on the same machine, your SherlockML server. When you see the word `localhost` below, that's what it means: connect to a database running on the same server as I'm on. Other than that, everything we'll learn here applies to connecting to MongoDB on remote servers.
#
# ## How MongoDB is structured
#
# MongoDB is a document-oriented database, as we learnt about during the workshop presentation. MongoDB "documents" are like Python dictionaries: a list of key-value pairs that describe some particular thing. Documents are stored in a structure called a "collection," which is like a list of dictionaries in Python. Most of the work we do in MongoDB will be adding documents to a collection, and asking that collection to return documents that match particular queries.
#
# Collections themselves are grouped into "databases," and each MongoDB server can support multiple databases.
#
# ## Connecting to MongoDB and inserting a document
#
# First we'll import the `MongoClient` class from the `pymongo` module, and instantiate a `MongoClient` object. We'll pass the string `localhost` as the first argument, which tells `pymongo` to connect to the MongoDB server running on this machine.

# %%
from __future__ import print_function
from pymongo import MongoClient

client = MongoClient('localhost')

print(type(client))
# Out:
# <class 'pymongo.mongo_client.MongoClient'>

# %%
# Delete the `fellowship` database when starting the notebook again from scratch.
client.drop_database('fellowship')

# %% [markdown]
# One thing you can do with a `MongoClient` object is call its `.database_names()` method, which returns a list of all the databases on the server.

# %%
print(client.database_names())
# Out:
# [u'local', u'admin']

# %% [markdown]
# You should see only one database right now---`local`. The `local` database is for MongoDB's internal use, so we won't mess with it. Instead, we'll use the `MongoClient` object to get another object that represents a new database, like so:

# %%
db = client['fellowship']

# %% [markdown]
# Note: We haven't done anything at this point to explicitly create the `workshop` database! MongoDB automatically creates databases when you first use them.
#
# This `Database` object supports several interesting methods, among them `.collection_names()`, which shows all of the collections in this database:

# %%
print(db.collection_names())
# Out:
# []

# %% [markdown]
# It's an empty list right now (except maybe for a `system.indexes` collection, which is for internal MongoDB use and which you can ignore if it exists), because we haven't made any collections yet! Using the `Database` object as a dictionary, we can get an object representing a collection:

# %%
coll = db['kittens']
print(coll)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'fellowship'), u'kittens')

# %% [markdown]
# Now we're in business. Let's insert our first document into the collection, using the collection's `.insert_one()` method. In between the parentheses of the `.insert_one()` method, we need to supply an expression that evaluates to a Python dictionary. PyMongo will convert this dictionary into a MongoDB document, and then add that document to the collection. Calling the `.insert_one()` method evaluates to a MongoDB `InsertOneResult` object, from which we can retrieve a randomly generated number that uniquely identifies the record that we just added from the `inserted_id` attribute:

# %%
result = coll.insert_one({'name': 'Fluffy', 'favourite_colour': 'chartreuse', 'lbs': 9.5})
print(result.inserted_id)
# Out:
# 5888967410f3fc0e1d2621f9

# %% [markdown]
# Let's insert a few more records!

# %%
coll.insert_one({'name': 'Monsieur Whiskeurs', 'favourite_colour': 'cerulean', 'lbs': 10.8})
coll.insert_one({'name': 'Grandpa Pants', 'favourite_colour': 'mauve', 'lbs': 14.1})
coll.insert_one({'name': 'Susan B. Meownthony', 'favourite_colour': 'cerulean', 'lbs': 9.0});

# %% [markdown]
# ## Finding a document
#
# Of course, inserting documents on its own is not very useful. We'd like to be able to retrieve them later. To do so, we can use the `.find_one()` method of a collection object. Between the parentheses of the `.find_one()` call, we give a Python dictionary that tells MongoDB which documents to return. The `.find_one()` evaluates to the document that has an exact match for whichever key-value pairs are specified in the dictionary. To demonstrate:

# %%
coll.find_one({'name': 'Monsieur Whiskeurs'})
# Out:
# {u'_id': ObjectId('5888967410f3fc0e1d2621fa'),
#  u'favourite_colour': u'cerulean',
#  u'lbs': 10.8,
#  u'name': u'Monsieur Whiskeurs'}

# %% [markdown]
# If more than one document had the value `Monsieur Whiskeurs` for the key `name`, MongoDB would have returned only the first matching document. If no documents match, this happens:

# %%
val = coll.find_one({'name': 'Big Shoes'})
print(val)
# Out:
# None

# %% [markdown]
# ... the method evaluates to `None`.
#
# You may have noticed the key `_id` in the document above. We didn't specify that key when we created the document, so where did it come from? It turns out that unless we specify the `_id` key manually, MongoDB will add it automatically and give it a randomly generated and unique `ObjectId` object as a value.
#
# Let's do that `.find_one()` call again and see what else we can do with it.

# %%
doc = coll.find_one({'name': 'Monsieur Whiskeurs'})
print(type(doc))
print(doc['favourite_colour'])
# Out:
# <type 'dict'>
# cerulean

# %% [markdown]
# As you can see, the value returned from `.find_one()` is just a Python dictionary. We can use it in any of the ways we usually use Python dictionaries--by getting a value for one of its keys, for example.

# %% [markdown]
# Use the `.find_one()` method to print out the `favourite_colour` value for our kitten named `Grandpa Pants`.

# %%
print(coll.find_one({'name': 'Grandpa Pants'})['favourite_colour'])
# Out:
# mauve

# %% [markdown]
# ## Finding more than one document
#
# The collection object has a method `.find()` that allows you to access every document in the collection. It doesn't return a list, but a weird thing called a `Cursor`. To get data from a cursor, you either have to use it in a `for` loop like this:

# %%
for doc in coll.find():
    print(doc)
# Out:
# {u'favourite_colour': u'chartreuse', u'lbs': 9.5, u'_id': ObjectId('5888967410f3fc0e1d2621f9'), u'name': u'Fluffy'}
# {u'favourite_colour': u'cerulean', u'lbs': 10.8, u'_id': ObjectId('5888967410f3fc0e1d2621fa'), u'name': u'Monsieur Whiskeurs'}
# {u'favourite_colour': u'mauve', u'lbs': 14.1, u'_id': ObjectId('5888967410f3fc0e1d2621fb'), u'name': u'Grandpa Pants'}
# {u'favourite_colour': u'cerulean', u'lbs': 9.0, u'_id': ObjectId('5888967410f3fc0e1d2621fc'), u'name': u'Susan B. Meownthony'}

# %% [markdown]
# ... or explicitly convert it to a list, with the `list()` function:

# %%
documents = list(coll.find())
documents
# Out:
# [{u'_id': ObjectId('5888967410f3fc0e1d2621f9'),
#   u'favourite_colour': u'chartreuse',
#   u'lbs': 9.5,
#   u'name': u'Fluffy'},
#  {u'_id': ObjectId('5888967410f3fc0e1d2621fa'),
#   u'favourite_colour': u'cerulean',
#   u'lbs': 10.8,
#   u'name': u'Monsieur Whiskeurs'},
#  {u'_id': ObjectId('5888967410f3fc0e1d2621fb'),
#   u'favourite_colour': u'mauve',
#   u'lbs': 14.1,
#   u'name': u'Grandpa Pants'},
#  {u'_id': ObjectId('5888967410f3fc0e1d2621fc'),
#   u'favourite_colour': u'cerulean',
#   u'lbs': 9.0,
#   u'name': u'Susan B. Meownthony'}]

# %% [markdown]
# We can also pass a dictionary to `.find()` to tell MongoDB to only return a subset of documents, namely, only those documents that match the key-value pairs in the dictionary we put in the parentheses. For example, to fetch only those kittens whose `favourite_colour` is `cerulean`:

# %%
cerulean_lovers = list(coll.find({'favourite_colour': 'cerulean'}))
cerulean_lovers
# Out:
# [{u'_id': ObjectId('5888967410f3fc0e1d2621fa'),
#   u'favourite_colour': u'cerulean',
#   u'lbs': 10.8,
#   u'name': u'Monsieur Whiskeurs'},
#  {u'_id': ObjectId('5888967410f3fc0e1d2621fc'),
#   u'favourite_colour': u'cerulean',
#   u'lbs': 9.0,
#   u'name': u'Susan B. Meownthony'}]

# %% [markdown]
# Write a list comprehension that evaluates to a list of the names of kittens whose weight is over 10 lbs.

# %%
[kitten['name'] for kitten in coll.find() if kitten['lbs'] > 10]
# Out:
# [u'Monsieur Whiskeurs', u'Grandpa Pants']

# %% [markdown]
# ## Simple aggregations
#
# You can ask MongoDB how many documents are in a collection with the collection's `.count()` method:

# %%
coll.count()
# Out:
# 4

# %% [markdown]
# It's also easy to get a list of distinct values there are for a particular field, using the `distinct` method:

# %%
coll.distinct('favourite_colour')
# Out:
# [u'chartreuse', u'cerulean', u'mauve']

# %% [markdown]
# ## Removing documents
#
# You can remove documents from a collection with the `.delete_many()` method, passing in a dictionary that describes which documents you want to remove. For example, to remove any documents where the `name` key has the value `Fluffy`:

# %%
coll.delete_many({'name': 'Fluffy'})
list(coll.find())
# Out:
# [{u'_id': ObjectId('5888967410f3fc0e1d2621fa'),
#   u'favourite_colour': u'cerulean',
#   u'lbs': 10.8,
#   u'name': u'Monsieur Whiskeurs'},
#  {u'_id': ObjectId('5888967410f3fc0e1d2621fb'),
#   u'favourite_colour': u'mauve',
#   u'lbs': 14.1,
#   u'name': u'Grandpa Pants'},
#  {u'_id': ObjectId('5888967410f3fc0e1d2621fc'),
#   u'favourite_colour': u'cerulean',
#   u'lbs': 9.0,
#   u'name': u'Susan B. Meownthony'}]

# %% [markdown]
# You can see that `Fluffy` has now gone missing. You can also easily remove *all* documents from a collection, using the `.remove_many()` method with an empty dictionary. **WARNING**: Don't run this cell unless you want to remove everything you've inserted so far!

# %%
# WARNING: Will delete *all* documents from the collection.
coll.delete_many({})
list(coll.find())
# Out:
# []

# %% [markdown]
# ## More sophisticated queries
#
# We can be a bit more specific about which documents we want from the collection using MongoDB *query selectors*. Query selectors take the form of dictionaries that we pass to the `.find()` method. Keys in this dictionary should be the field that you want to match against, and the value for such a key should be *another* dictionary, that has as its key a MongoDB query operator (listed below), and as its value the number to go with the operator. Here's an example, to make it more clear, searching our collection of kittens for documents where the `lbs` field is greater than `10`:

# %%
list(coll.find({'lbs': {'$gt': 10}}))
# Out:
# []

# %% [markdown]
# Other operators that are supported ([full list here](https://docs.mongodb.com/manual/reference/operator/query/#query-selectors)):
#
# * `$gt`: greater than
# * `$gte`: greater than or equal to
# * `$lt`: less than
# * `$lte`: less than or equal to
# * `$ne`: not equal to
#
# You can combine more than one operator for a particular field, in which case MongoDB will find documents that match *all* criteria:

# %%
list(coll.find({'lbs': {'$gt': 9, '$lt': 11}}))
# Out:
# []

# %% [markdown]
# You can also include conditions for more than one field in the dictionary, in which case MongoDB will find documents that match those criteria for each respective field:

# %%
list(coll.find({'favourite_colour': 'cerulean'}))
# Out:
# []

# %%
list(coll.find({'favourite_colour': 'cerulean', 'name': {'$ne': 'Monsieur Whiskeurs'}}))
# Out:
# []

# %% [markdown]
# ### Regular expression searches
#
# Another valuable search criterion that MongoDB supports is `$regex`, which will return documents that match a regular expression for a particular field. For example, to find all kittens whose name ends with the letter `y`:

# %%
list(coll.find({'name': {'$regex': 'y$'}}))
# Out:
# []

# %% [markdown]
# Write a call to `.find()` that returns all kittens whose favourite colour begins with the letter `c`.

# %%
list(coll.find({'favourite_colour': {'$regex': '^c'}}))
# Out:
# []

# %% [markdown]
# ## Sorting and limiting
#
# Results from `.find()` aren't returned in a particular order. You may find it helpful for this reason to sort the results. You can specify a sort order for results from the `.find()` method by appending a call to the `.sort()` method. It looks like this:

# %%
list(coll.find().sort('lbs'))
# Out:
# []

# %% [markdown]
# The parameter you pass to `.sort()` specifies which field the documents should be sorted by. Specifying descending order is easy:

# %%
list(coll.find().sort('lbs', -1))
# Out:
# []

# %% [markdown]
# (The `-1` means 'in reverse order'.) The `.sort()` method works even if you've specified query selectors in the call to `.find()`:

# %%
list(coll.find({'lbs': {'$gt': 9.0}}).sort('name'))
# Out:
# []

# %% [markdown]
# You can also limit the number of results returned from `.find()` using the `.limit()` method, which, like `.sort()`, gets called on the result of `.find()`. To return only two kittens:

# %%
list(coll.find().limit(2))
# Out:
# []

# %% [markdown]
# Search for all kittens weighing less than 10 pounds, limit to one result:

# %%
list(coll.find({'lbs': {'$lt': 10.0}}).limit(1))
# Out:
# []

# %% [markdown]
# You can put a `.limit()` after a `.sort()` to get only the first few results from a sorted list of documents. So, for example, to get only the heaviest cat:

# %%
list(coll.find().sort('lbs', -1).limit(1))
# Out:
# []

# %% [markdown]
# ## Only get certain fields
#
# If we want our result to only include certain key-value pairs from the document, we can provide a second argument to the `find` method. This argument should be a dictionary whose keys are the fields we want included, and whose values are all `1`. For example, to find all kittens whose favourite colour is `cerulean`, but only return their names, we could do this:

# %%
list(coll.find({'favourite_colour': 'cerulean'}, {'name': 1}))
# Out:
# []

# %% [markdown]
# The `_id` field is always included by default. If we want to get rid of it, we can include the `_id` key in our list of fields, giving it a `0` (instead of a `1`):

# %%
list(coll.find({'favourite_colour': 'cerulean'}, {'name': 1, '_id': 0}))
# Out:
# []

# %% [markdown]
# ## Let's get real
#
# I want to take you through a real-world example of consuming data from a source, putting it into MongoDB, then querying MongoDB to find interesting stuff in that data. Specifically, we're going to fetch a big CSV of historic data about congress members from the "Bulk Data" section of [govtrack.us](https://www.govtrack.us/developers/data). [Here's the file](https://www.govtrack.us/data/congress-legislators/legislators-historic.csv), which contains a row for every member of Congress in the history of the United States (who isn't currently a sitting member).

# %% [markdown]
# Let's play with the `csv` library's `DictReader` class to see what the data looks like.

# %%
import csv
rows = csv.DictReader(open('legislators-historic.csv'))
all_rows = list(rows)
all_rows[0]
# Out:
# {'address': '',
#  'ballotpedia_id': '',
#  'bioguide_id': 'B000226',
#  'birthday': '1745-04-02',
#  'contact_form': '',
#  'cspan_id': '',
#  'district': '',
#  'facebook': '',
#  'facebook_id': '',
#  'first_name': 'Richard',
#  'gender': 'M',
#  'govtrack_id': '401222',
#  'icpsr_id': '507',
#  'last_name': 'Bassett',
#  'lis_id': '',
#  'opensecrets_id': '',
#  'party': 'Anti-Administration',
#  'phone': '',
#  'rss_url': '',
#  'state': 'DE',
#  'thomas_id': '',
#  'twitter': '',
#  'type': 'sen',
#  'url': '',
#  'votesmart_id': '',
#  'washington_post_id': '',
#  'wikipedia_id': '',
#  'youtube': '',
#  'youtube_id': ''}

# %%
# Drop the `legislators` collection when starting the notebook again from scratch.
db.drop_collection('legislators')

# %% [markdown]
# What we seem to have here is a dictionary that describes a member of congress. This happens to be one [Richard Bassett](http://en.wikipedia.org/wiki/Richard_Bassett_(politician)), born in 1745. So how about putting all those rows into MongoDB? Here's how it would go. It's pretty simple--we'll create a separate collection in our database for these legislators, called `legislators`.

# %%
coll = db['legislators']

# %% [markdown]
# Now, loop through the rows of the table and just insert each dictionary from `DictReader` straight into MongoDB:

# %%
for row in all_rows:
    coll.insert_one(row)

# %% [markdown]
# At this point, the number of documents in the database should match the number of rows in the CSV file. Let's make sure.

# %%
len(all_rows) == coll.count()
# Out:
# True

# %% [markdown]
# And how many exactly is that?

# %%
coll.count()
# Out:
# 11807

# %% [markdown]
# Eleven thousand legislators. Not exactly "big data", but hopefully you can still see the benefit of having this data in one place without having to re-download and parse the data each time we want to use it.
#
# ### Meet the press
#
# Let's do some queries on our data now. Make a list of all legislators who are women:

# %%
list(coll.find({'gender': 'F'}))
# Out:
# [{u'_id': ObjectId('5888967810f3fc0e1d264d28'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'L000381',
#   u'birthday': u'1929-01-03',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'3',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Marilyn',
#   u'gender': u'F',
#   u'govtrack_id': u'406873',
#   u'icpsr_id': u'14251',
#   u'last_name': u'Lloyd',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'TN',
#   u'thomas_id': u'00698',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264d99'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'G000408',
#   u'birthday': u'1958-06-05',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'2',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Enid',
#   u'gender': u'F',
#   u'govtrack_id': u'411214',
#   u'icpsr_id': u'29575',
#   u'last_name': u'Greene Waldholtz',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'UT',
#   u'thomas_id': u'01192',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Enid Greene',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264de1'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'C000345',
#   u'birthday': u'1938-01-27',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Helen',
#   u'gender': u'F',
#   u'govtrack_id': u'400575',
#   u'icpsr_id': u'29514',
#   u'last_name': u'Chenoweth-Hage',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'ID',
#   u'thomas_id': u'00194',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e18'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'C000494',
#   u'birthday': u'1934-09-16',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Eva',
#   u'gender': u'F',
#   u'govtrack_id': u'400532',
#   u'icpsr_id': u'29382',
#   u'last_name': u'Clayton',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NC',
#   u'thomas_id': u'00204',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e33'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M000628',
#   u'birthday': u'1926-04-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'17',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Carrie',
#   u'gender': u'F',
#   u'govtrack_id': u'400511',
#   u'icpsr_id': u'29334',
#   u'last_name': u'Meek',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'00789',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Carrie P. Meek',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e35'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M000797',
#   u'birthday': u'1927-12-06',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'2',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Patsy',
#   u'gender': u'F',
#   u'govtrack_id': u'400554',
#   u'icpsr_id': u'10757',
#   u'last_name': u'Mink',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'HI',
#   u'thomas_id': u'00815',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Patsy Mink',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e37'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M000941',
#   u'birthday': u'1931-02-12',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'8',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Constance',
#   u'gender': u'F',
#   u'govtrack_id': u'400524',
#   u'icpsr_id': u'15434',
#   u'last_name': u'Morella',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'MD',
#   u'thomas_id': u'00833',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e3a'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'R000281',
#   u'birthday': u'1956-12-19',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'13',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Lynn',
#   u'gender': u'F',
#   u'govtrack_id': u'400528',
#   u'icpsr_id': u'29531',
#   u'last_name': u'Rivers',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'MI',
#   u'thomas_id': u'00966',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Lynn N. Rivers',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e3c'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'R000465',
#   u'birthday': u'1929-09-19',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Marge',
#   u'gender': u'F',
#   u'govtrack_id': u'400533',
#   u'icpsr_id': u'14855',
#   u'last_name': u'Roukema',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NJ',
#   u'thomas_id': u'00990',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e48'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'T000253',
#   u'birthday': u'1951-01-12',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Karen',
#   u'gender': u'F',
#   u'govtrack_id': u'400509',
#   u'icpsr_id': u'29330',
#   u'last_name': u'Thurman',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'01157',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e5d'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000601',
#   u'birthday': u'1936-07-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Elizabeth',
#   u'gender': u'F',
#   u'govtrack_id': u'300035',
#   u'icpsr_id': u'40303',
#   u'last_name': u'Dole',
#   u'lis_id': u'S292',
#   u'opensecrets_id': u'N00008071',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NC',
#   u'thomas_id': u'01698',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://dole.senate.gov/',
#   u'votesmart_id': u'41533',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e60'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000549',
#   u'birthday': u'1941-07-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'8',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jennifer',
#   u'gender': u'F',
#   u'govtrack_id': u'400117',
#   u'icpsr_id': u'39312',
#   u'last_name': u'Dunn',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00007823',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'WA',
#   u'thomas_id': u'00324',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/dunn',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jennifer Dunn',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e6e'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M001145',
#   u'birthday': u'1955-05-18',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'4',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Denise',
#   u'gender': u'F',
#   u'govtrack_id': u'400250',
#   u'icpsr_id': u'20318',
#   u'last_name': u'Majette',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00025138',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'GA',
#   u'thomas_id': u'01719',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/majette',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e70'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M000316',
#   u'birthday': u'1947-03-18',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Karen',
#   u'gender': u'F',
#   u'govtrack_id': u'400258',
#   u'icpsr_id': u'29535',
#   u'last_name': u'McCarthy',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00005119',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'MO',
#   u'thomas_id': u'00756',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://mccarthy.house.gov/',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Karen McCarthy',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e99'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001035',
#   u'birthday': u'1957-04-05',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'13',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Katherine',
#   u'gender': u'F',
#   u'govtrack_id': u'400167',
#   u'icpsr_id': u'20314',
#   u'last_name': u'Harris',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00024882',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'01714',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/harris',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e9a'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001033',
#   u'birthday': u'1962-04-04',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'4',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Melissa',
#   u'gender': u'F',
#   u'govtrack_id': u'400168',
#   u'icpsr_id': u'20133',
#   u'last_name': u'Hart',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00009715',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'PA',
#   u'thomas_id': u'01666',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://hart.house.gov',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Melissa Hart (politician)',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ea1'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'J000163',
#   u'birthday': u'1935-01-05',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Nancy',
#   u'gender': u'F',
#   u'govtrack_id': u'400205',
#   u'icpsr_id': u'15028',
#   u'last_name': u'Johnson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00000561',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CT',
#   u'thomas_id': u'00602',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/nancyjohnson',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ea2'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'K000078',
#   u'birthday': u'1936-09-26',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'19',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Sue',
#   u'gender': u'F',
#   u'govtrack_id': u'400213',
#   u'icpsr_id': u'29544',
#   u'last_name': u'Kelly',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00001020',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NY',
#   u'thomas_id': u'00624',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/suekelly',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Sue W. Kelly',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ea6'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'L000035',
#   u'birthday': u'1960-09-30',
#   u'contact_form': u'',
#   u'cspan_id': u'26202',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Blanche',
#   u'gender': u'F',
#   u'govtrack_id': u'300068',
#   u'icpsr_id': u'29305',
#   u'last_name': u'Lincoln',
#   u'lis_id': u'S269',
#   u'opensecrets_id': u'N00008092',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'AR',
#   u'thomas_id': u'01570',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://lincoln.senate.gov/',
#   u'votesmart_id': u'26723',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Blanche Lincoln',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ea8'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M000523',
#   u'birthday': u'1955-03-17',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'4',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Cynthia',
#   u'gender': u'F',
#   u'govtrack_id': u'400513',
#   u'icpsr_id': u'29344',
#   u'last_name': u'McKinney',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00002511',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'GA',
#   u'thomas_id': u'00780',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264eaa'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'N000143',
#   u'birthday': u'1948-01-22',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'3',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Anne',
#   u'gender': u'F',
#   u'govtrack_id': u'400294',
#   u'icpsr_id': u'29725',
#   u'last_name': u'Northup',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00003392',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'KY',
#   u'thomas_id': u'01508',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/northup',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ec0'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'S001166',
#   u'birthday': u'1953-06-22',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'22',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Shelley',
#   u'gender': u'F',
#   u'govtrack_id': u'412185',
#   u'icpsr_id': u'20541',
#   u'last_name': u'Sekula-Gibbs',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00028489',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'TX',
#   u'thomas_id': u'01819',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ec3'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001258',
#   u'birthday': u'1955-08-02',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'2',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Nancy',
#   u'gender': u'F',
#   u'govtrack_id': u'412210',
#   u'icpsr_id': u'20721',
#   u'last_name': u'Boyda',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00026434',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'KS',
#   u'thomas_id': u'01852',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://boyda.house.gov',
#   u'votesmart_id': u'34790',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Nancy Boyda',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ec6'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'C000191',
#   u'birthday': u'1938-07-08',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'7',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Julia',
#   u'gender': u'F',
#   u'govtrack_id': u'400067',
#   u'icpsr_id': u'29720',
#   u'last_name': u'Carson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00003758',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'IN',
#   u'thomas_id': u'01473',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://juliacarson.house.gov',
#   u'votesmart_id': u'359',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Julia Carson',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ec7'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'C001041',
#   u'birthday': u'1947-10-26',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Hillary',
#   u'gender': u'F',
#   u'govtrack_id': u'300022',
#   u'icpsr_id': u'40105',
#   u'last_name': u'Clinton',
#   u'lis_id': u'S278',
#   u'opensecrets_id': u'N00000019',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NY',
#   u'thomas_id': u'01631',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://clinton.senate.gov',
#   u'votesmart_id': u'55463',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ec9'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'C000962',
#   u'birthday': u'1946-11-30',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'0',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Barbara',
#   u'gender': u'F',
#   u'govtrack_id': u'400088',
#   u'icpsr_id': u'29584',
#   u'last_name': u'Cubin',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00006242',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'WY',
#   u'thomas_id': u'00254',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/cubin',
#   u'votesmart_id': u'22044',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Barbara Cubin',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ecb'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000597',
#   u'birthday': u'1950-06-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jo Ann',
#   u'gender': u'F',
#   u'govtrack_id': u'400095',
#   u'icpsr_id': u'20141',
#   u'last_name': u'Davis',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00013078',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'VA',
#   u'thomas_id': u'01672',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://joanndavis.house.gov',
#   u'votesmart_id': u'24970',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jo Ann Davis',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ece'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000605',
#   u'birthday': u'1949-11-20',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'2',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Thelma',
#   u'gender': u'F',
#   u'govtrack_id': u'400658',
#   u'icpsr_id': u'20534',
#   u'last_name': u'Drake',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027281',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'VA',
#   u'thomas_id': u'01808',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://drake.house.gov',
#   u'votesmart_id': u'8231',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Thelma Drake',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264edd'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H000762',
#   u'birthday': u'1939-04-04',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Darlene',
#   u'gender': u'F',
#   u'govtrack_id': u'400186',
#   u'icpsr_id': u'29750',
#   u'last_name': u'Hooley',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00007700',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'OR',
#   u'thomas_id': u'01491',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/hooley',
#   u'votesmart_id': u'429',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Darlene Hooley',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ee2'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'J000284',
#   u'birthday': u'1949-09-10',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'11',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Stephanie',
#   u'gender': u'F',
#   u'govtrack_id': u'400208',
#   u'icpsr_id': u'29930',
#   u'last_name': u'Jones',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00003561',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'OH',
#   u'thomas_id': u'01581',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/tubbsjones',
#   u'votesmart_id': u'23325',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Stephanie Tubbs Jones',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ef0'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M000714',
#   u'birthday': u'1938-09-07',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'37',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Juanita',
#   u'gender': u'F',
#   u'govtrack_id': u'400275',
#   u'icpsr_id': u'29586',
#   u'last_name': u'Millender-McDonald',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00006811',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'00805',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://millender-mcdonald.house.gov',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Juanita Millender-McDonald',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ef1'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M001152',
#   u'birthday': u'1949-01-27',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'4',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Marilyn',
#   u'gender': u'F',
#   u'govtrack_id': u'400287',
#   u'icpsr_id': u'20311',
#   u'last_name': u'Musgrave',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00025054',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CO',
#   u'thomas_id': u'01711',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://musgrave.house.gov',
#   u'votesmart_id': u'2703',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Marilyn Musgrave',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ef6'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'P000555',
#   u'birthday': u'1951-07-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'15',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Deborah',
#   u'gender': u'F',
#   u'govtrack_id': u'400327',
#   u'icpsr_id': u'29390',
#   u'last_name': u'Pryce',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00003504',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'OH',
#   u'thomas_id': u'00933',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/pryce',
#   u'votesmart_id': u'27020',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Deborah Pryce',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f03'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'W000789',
#   u'birthday': u'1960-12-30',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Heather',
#   u'gender': u'F',
#   u'govtrack_id': u'400434',
#   u'icpsr_id': u'29779',
#   u'last_name': u'Wilson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00006546',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NM',
#   u'thomas_id': u'01539',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://wilson.house.gov',
#   u'votesmart_id': u'22687',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Heather Wilson',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f0b'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001253',
#   u'birthday': u'1962-01-22',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'8',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Melissa',
#   u'gender': u'F',
#   u'govtrack_id': u'400631',
#   u'icpsr_id': u'20509',
#   u'last_name': u'Bean',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00024875',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'IL',
#   u'thomas_id': u'01782',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/bean',
#   u'votesmart_id': u'33448',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Melissa Bean',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f13'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001247',
#   u'birthday': u'1943-10-05',
#   u'contact_form': u'',
#   u'cspan_id': u'1003557',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Virginia',
#   u'gender': u'F',
#   u'govtrack_id': u'400051',
#   u'icpsr_id': u'20313',
#   u'last_name': u'Brown-Waite',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00024777',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'01713',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/brown-waite',
#   u'votesmart_id': u'8077',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Ginny Brown-Waite',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f19'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000608',
#   u'birthday': u'1957-12-10',
#   u'contact_form': u'',
#   u'cspan_id': u'1030596',
#   u'district': u'3',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Kathleen',
#   u'gender': u'F',
#   u'govtrack_id': u'412273',
#   u'icpsr_id': u'20945',
#   u'last_name': u'Dahlkemper',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00029414',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'PA',
#   u'thomas_id': u'01951',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://dahlkemper.house.gov',
#   u'votesmart_id': u'102423',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Kathy Dahlkemper',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f24'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'F000453',
#   u'birthday': u'1954-12-09',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Mary',
#   u'gender': u'F',
#   u'govtrack_id': u'412230',
#   u'icpsr_id': u'20742',
#   u'last_name': u'Fallin',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027781',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'OK',
#   u'thomas_id': u'01872',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://fallin.house.gov',
#   u'votesmart_id': u'1699',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Mary Fallin',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f28'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001044',
#   u'birthday': u'1958-03-01',
#   u'contact_form': u'',
#   u'cspan_id': u'1031342',
#   u'district': u'11',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Deborah',
#   u'gender': u'F',
#   u'govtrack_id': u'412279',
#   u'icpsr_id': u'20913',
#   u'last_name': u'Halvorson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00029377',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'IL',
#   u'thomas_id': u'01919',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://halvorson.house.gov',
#   u'votesmart_id': u'9531',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Debbie Halvorson',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f2a'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001037',
#   u'birthday': u'1970-12-03',
#   u'contact_form': u'',
#   u'cspan_id': u'22061',
#   u'district': u'0',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Stephanie',
#   u'gender': u'F',
#   u'govtrack_id': u'400443',
#   u'icpsr_id': u'20349',
#   u'last_name': u'Herseth Sandlin',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00024773',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'SD',
#   u'thomas_id': u'01760',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/herseth',
#   u'votesmart_id': u'48367',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Stephanie Herseth Sandlin',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f32'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'K000180',
#   u'birthday': u'1945-06-25',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'13',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Carolyn',
#   u'gender': u'F',
#   u'govtrack_id': u'400217',
#   u'icpsr_id': u'29733',
#   u'last_name': u'Kilpatrick',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00004005',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'MI',
#   u'thomas_id': u'01497',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/kilpatrick',
#   u'votesmart_id': u'522',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f33'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'K000372',
#   u'birthday': u'1949-04-30',
#   u'contact_form': u'',
#   u'cspan_id': u'1021679',
#   u'district': u'15',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Mary Jo',
#   u'gender': u'F',
#   u'govtrack_id': u'412285',
#   u'icpsr_id': u'20942',
#   u'last_name': u'Kilroy',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027778',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'OH',
#   u'thomas_id': u'01948',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://kilroy.house.gov',
#   u'votesmart_id': u'95759',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Mary Jo Kilroy',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f35'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'K000370',
#   u'birthday': u'1944-02-25',
#   u'contact_form': u'',
#   u'cspan_id': u'1030644',
#   u'district': u'24',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Suzanne',
#   u'gender': u'F',
#   u'govtrack_id': u'412288',
#   u'icpsr_id': u'20911',
#   u'last_name': u'Kosmas',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00029370',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'01917',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.kosmas.house.gov',
#   u'votesmart_id': u'12851',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Suzanne Kosmas',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f38'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M001172',
#   u'birthday': u'1956-04-27',
#   u'contact_form': u'',
#   u'cspan_id': u'1030430',
#   u'district': u'4',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Betsy',
#   u'gender': u'F',
#   u'govtrack_id': u'412298',
#   u'icpsr_id': u'20905',
#   u'last_name': u'Markey',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00029128',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CO',
#   u'thomas_id': u'01911',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://betsymarkey.house.gov',
#   u'votesmart_id': u'106225',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Betsy Markey',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f54'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'S001153',
#   u'birthday': u'1957-10-20',
#   u'contact_form': u'',
#   u'cspan_id': u'85603',
#   u'district': u'32',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Hilda',
#   u'gender': u'F',
#   u'govtrack_id': u'400384',
#   u'icpsr_id': u'20105',
#   u'last_name': u'Solis',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00009586',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'01636',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://solis.house.gov',
#   u'votesmart_id': u'3585',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Hilda Solis',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f5a'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'T000057',
#   u'birthday': u'1951-11-15',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'10',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Ellen',
#   u'gender': u'F',
#   u'govtrack_id': u'400396',
#   u'icpsr_id': u'29705',
#   u'last_name': u'Tauscher',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00007422',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'01533',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/tauscher',
#   u'votesmart_id': u'94',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Ellen Tauscher',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f5f'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'W000794',
#   u'birthday': u'1933-11-12',
#   u'contact_form': u'',
#   u'cspan_id': u'4372',
#   u'district': u'33',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Diane',
#   u'gender': u'F',
#   u'govtrack_id': u'400423',
#   u'icpsr_id': u'20106',
#   u'last_name': u'Watson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00013744',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'01682',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/watson',
#   u'votesmart_id': u'3587',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Diane Watson',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f6b'),
#   u'address': u'1030 Longworth House Office Building;  20515-0308',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'G000554',
#   u'birthday': u'1970-06-08',
#   u'contact_form': u'',
#   u'cspan_id': u'1021830',
#   u'district': u'8',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Gabrielle',
#   u'gender': u'F',
#   u'govtrack_id': u'412188',
#   u'icpsr_id': u'20701',
#   u'last_name': u'Giffords',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027829',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'AZ',
#   u'thomas_id': u'01831',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://giffords.house.gov',
#   u'votesmart_id': u'28507',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Gabrielle Giffords',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f6c'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H000213',
#   u'birthday': u'1945-06-28',
#   u'contact_form': u'',
#   u'cspan_id': u'16717',
#   u'district': u'36',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jane',
#   u'gender': u'F',
#   u'govtrack_id': u'400166',
#   u'icpsr_id': u'29318',
#   u'last_name': u'Harman',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00006750',
#   u'party': u'Democrat',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'00502',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/harman',
#   u'votesmart_id': u'26768',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jane Harman',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f7a'),
#   u'address': u'284 RUSSELL SENATE OFFICE BUILDING WASHINGTON DC 20510',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001016',
#   u'birthday': u'1943-07-22',
#   u'contact_form': u'http://www.hutchison.senate.gov/?p=email_kay',
#   u'cspan_id': u'24713',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Kay',
#   u'gender': u'F',
#   u'govtrack_id': u'300054',
#   u'icpsr_id': u'49306',
#   u'last_name': u'Hutchison',
#   u'lis_id': u'S235',
#   u'opensecrets_id': u'N00005675',
#   u'party': u'Republican',
#   u'phone': u'202-224-5922',
#   u'rss_url': u'',
#   u'state': u'TX',
#   u'thomas_id': u'01368',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://hutchison.senate.gov/',
#   u'votesmart_id': u'53349',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Kay Bailey Hutchison',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f80'),
#   u'address': u'154 RUSSELL SENATE OFFICE BUILDING WASHINGTON DC 20510',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'S000663',
#   u'birthday': u'1947-02-21',
#   u'contact_form': u'http://www.snowe.senate.gov/public/index.cfm/contact?p=email',
#   u'cspan_id': u'',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Olympia',
#   u'gender': u'F',
#   u'govtrack_id': u'300091',
#   u'icpsr_id': u'14661',
#   u'last_name': u'Snowe',
#   u'lis_id': u'S245',
#   u'opensecrets_id': u'N00000480',
#   u'party': u'Republican',
#   u'phone': u'202-224-5344',
#   u'rss_url': u'',
#   u'state': u'ME',
#   u'thomas_id': u'01085',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://snowe.senate.gov/',
#   u'votesmart_id': u'26885',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f84'),
#   u'address': u'216 Cannon HOB; Washington DC 20515-0924',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'A000366',
#   u'birthday': u'1956-12-14',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'24',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Sandy',
#   u'gender': u'F',
#   u'govtrack_id': u'412414',
#   u'icpsr_id': u'21120',
#   u'last_name': u'Adams',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00030926',
#   u'party': u'Republican',
#   u'phone': u'202-225-2706',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'02006',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://adams.house.gov/',
#   u'votesmart_id': u'31041',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Sandy Adams',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f8c'),
#   u'address': u'405 Cannon HOB; Washington DC 20515-2801',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001231',
#   u'birthday': u'1951-01-20',
#   u'contact_form': u'http://berkley.house.gov/contact/email.html',
#   u'cspan_id': u'',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Shelley',
#   u'gender': u'F',
#   u'govtrack_id': u'400024',
#   u'icpsr_id': u'29922',
#   u'last_name': u'Berkley',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00009818',
#   u'party': u'Democrat',
#   u'phone': u'202-225-5965',
#   u'rss_url': u'',
#   u'state': u'NV',
#   u'thomas_id': u'01576',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://berkley.house.gov',
#   u'votesmart_id': u'22744',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Shelley Berkley',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f8e'),
#   u'address': u'2113 Rayburn HOB; Washington DC 20515-1313',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001232',
#   u'birthday': u'1937-08-15',
#   u'contact_form': u'http://judybiggert.house.gov/ContactJudy.aspx',
#   u'cspan_id': u'57890',
#   u'district': u'13',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Judy',
#   u'gender': u'F',
#   u'govtrack_id': u'400027',
#   u'icpsr_id': u'29912',
#   u'last_name': u'Biggert',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00004762',
#   u'party': u'Republican',
#   u'phone': u'202-225-3515',
#   u'rss_url': u'',
#   u'state': u'IL',
#   u'thomas_id': u'01577',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://judybiggert.house.gov',
#   u'votesmart_id': u'6298',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Judy Biggert',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f90'),
#   u'address': u'104 Cannon HOB; Washington DC 20515-0545',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001228',
#   u'birthday': u'1961-10-24',
#   u'contact_form': u'http://www.house.gov/formbono/issue.htm',
#   u'cspan_id': u'',
#   u'district': u'45',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Mary',
#   u'gender': u'F',
#   u'govtrack_id': u'400039',
#   u'icpsr_id': u'29775',
#   u'last_name': u'Bono Mack',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00007068',
#   u'party': u'Republican',
#   u'phone': u'202-225-5330',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'01465',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://bono.house.gov',
#   u'votesmart_id': u'1434',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f93'),
#   u'address': u'1630 Longworth HOB; Washington DC 20515-3225',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001276',
#   u'birthday': u'1951-05-08',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'25',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Ann Marie',
#   u'gender': u'F',
#   u'govtrack_id': u'412456',
#   u'icpsr_id': u'21158',
#   u'last_name': u'Buerkle',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00031640',
#   u'party': u'Republican',
#   u'phone': u'202-225-3701',
#   u'rss_url': u'',
#   u'state': u'NY',
#   u'thomas_id': u'02045',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://buerkle.house.gov/',
#   u'votesmart_id': u'127047',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Ann Marie Buerkle',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fa1'),
#   u'address': u'1440 Longworth HOB; Washington DC 20515-3219',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001054',
#   u'birthday': u'1959-12-14',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'19',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Nan',
#   u'gender': u'F',
#   u'govtrack_id': u'412452',
#   u'icpsr_id': u'21155',
#   u'last_name': u'Hayworth',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00031124',
#   u'party': u'Republican',
#   u'phone': u'202-225-5441',
#   u'rss_url': u'',
#   u'state': u'NY',
#   u'thomas_id': u'02042',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://hayworth.house.gov/',
#   u'votesmart_id': u'127041',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Nan Hayworth',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fb0'),
#   u'address': u'230 Cannon HOB; Washington DC 20515-3309',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M001134',
#   u'birthday': u'1941-08-01',
#   u'contact_form': u'http://myrick.house.gov/zipauth.shtml',
#   u'cspan_id': u'1172',
#   u'district': u'9',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Sue',
#   u'gender': u'F',
#   u'govtrack_id': u'400288',
#   u'icpsr_id': u'29549',
#   u'last_name': u'Myrick',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00002327',
#   u'party': u'Republican',
#   u'phone': u'202-225-1976',
#   u'rss_url': u'',
#   u'state': u'NC',
#   u'thomas_id': u'00849',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/myrick',
#   u'votesmart_id': u'21789',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Sue Myrick',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fb8'),
#   u'address': u'1330 Longworth HOB; Washington DC 20515-0537',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'R000581',
#   u'birthday': u'1962-04-14',
#   u'contact_form': u'http://richardson.house.gov/IMA/issue_subscribe.htm',
#   u'cspan_id': u'1025575',
#   u'district': u'37',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Laura',
#   u'gender': u'F',
#   u'govtrack_id': u'412253',
#   u'icpsr_id': u'20752',
#   u'last_name': u'Richardson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00029112',
#   u'party': u'Democrat',
#   u'phone': u'202-225-7924',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'01883',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://richardson.house.gov/',
#   u'votesmart_id': u'69508',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Laura Richardson',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fbd'),
#   u'address': u'2464 Rayburn HOB; Washington DC 20515-3502',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'S001164',
#   u'birthday': u'1951-11-29',
#   u'contact_form': u'http://www.house.gov/schmidt/contact.shtml',
#   u'cspan_id': u'1017087',
#   u'district': u'2',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jean',
#   u'gender': u'F',
#   u'govtrack_id': u'412010',
#   u'icpsr_id': u'20540',
#   u'last_name': u'Schmidt',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027526',
#   u'party': u'Republican',
#   u'phone': u'202-225-3164',
#   u'rss_url': u'',
#   u'state': u'OH',
#   u'thomas_id': u'01815',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/schmidt',
#   u'votesmart_id': u'45475',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jean Schmidt',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fc2'),
#   u'address': u'1519 Longworth HOB; Washington DC 20515-3513',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'S001174',
#   u'birthday': u'1963-07-31',
#   u'contact_form': u'http://sutton.house.gov/about/emailform.cfm',
#   u'cspan_id': u'',
#   u'district': u'13',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Betty',
#   u'gender': u'F',
#   u'govtrack_id': u'412228',
#   u'icpsr_id': u'20740',
#   u'last_name': u'Sutton',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027901',
#   u'party': u'Democrat',
#   u'phone': u'202-225-3401',
#   u'rss_url': u'',
#   u'state': u'OH',
#   u'thomas_id': u'01870',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://sutton.house.gov',
#   u'votesmart_id': u'8394',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Betty Sutton',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fc6'),
#   u'address': u'2263 Rayburn HOB; Washington DC 20515-0506',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'W000738',
#   u'birthday': u'1937-11-03',
#   u'contact_form': u'http://woolsey.house.gov/contactemailform.asp',
#   u'cspan_id': u'26132',
#   u'district': u'6',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Lynn',
#   u'gender': u'F',
#   u'govtrack_id': u'400436',
#   u'icpsr_id': u'29309',
#   u'last_name': u'Woolsey',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00007458',
#   u'party': u'Democrat',
#   u'phone': u'202-225-5161',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'01242',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://woolsey.house.gov',
#   u'votesmart_id': u'26733',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Lynn Woolsey',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fc7'),
#   u'address': u'1711 Longworth HOB; Washington DC 20515-3226',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001062',
#   u'birthday': u'1958-08-27',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'26',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Kathleen',
#   u'gender': u'F',
#   u'govtrack_id': u'412497',
#   u'icpsr_id': u'21194',
#   u'last_name': u'Hochul',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00033055',
#   u'party': u'Democrat',
#   u'phone': u'202-225-5265',
#   u'rss_url': u'',
#   u'state': u'NY',
#   u'thomas_id': u'02088',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://hochul.house.gov/',
#   u'votesmart_id': u'129238',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Kathy Hochul',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fcb'),
#   u'address': u'2230 Rayburn HOB; Washington DC 20515-2508',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'E000172',
#   u'birthday': u'1950-09-16',
#   u'contact_form': u'http://www.house.gov/emerson/contact/',
#   u'cspan_id': u'46627',
#   u'district': u'8',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jo Ann',
#   u'gender': u'F',
#   u'govtrack_id': u'400121',
#   u'icpsr_id': u'29736',
#   u'last_name': u'Emerson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00005090',
#   u'party': u'Republican',
#   u'phone': u'202-225-4404',
#   u'rss_url': u'',
#   u'state': u'MO',
#   u'thomas_id': u'01481',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://emerson.house.gov',
#   u'votesmart_id': u'903',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jo Ann Emerson',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fda'),
#   u'address': u'521 Dirksen Senate Office Building Washington DC 20510',
#   u'ballotpedia_id': u'Kay Hagan',
#   u'bioguide_id': u'H001049',
#   u'birthday': u'1953-05-26',
#   u'contact_form': u'http://www.hagan.senate.gov/contact/',
#   u'cspan_id': u'1028015',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Kay',
#   u'gender': u'F',
#   u'govtrack_id': u'412324',
#   u'icpsr_id': u'40907',
#   u'last_name': u'Hagan',
#   u'lis_id': u'S320',
#   u'opensecrets_id': u'N00029617',
#   u'party': u'Democrat',
#   u'phone': u'202-224-6342',
#   u'rss_url': u'http://www.hagan.senate.gov/rss',
#   u'state': u'NC',
#   u'thomas_id': u'01902',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://www.hagan.senate.gov',
#   u'votesmart_id': u'21082',
#   u'washington_post_id': u'gIQA2GXW9O',
#   u'wikipedia_id': u'Kay Hagan',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fdd'),
#   u'address': u'703 Hart Senate Office Building Washington DC 20510',
#   u'ballotpedia_id': u'Mary Landrieu',
#   u'bioguide_id': u'L000550',
#   u'birthday': u'1955-11-23',
#   u'contact_form': u'http://www.landrieu.senate.gov/?p=contact',
#   u'cspan_id': u'22357',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Mary',
#   u'gender': u'F',
#   u'govtrack_id': u'300063',
#   u'icpsr_id': u'49702',
#   u'last_name': u'Landrieu',
#   u'lis_id': u'S258',
#   u'opensecrets_id': u'N00005395',
#   u'party': u'Democrat',
#   u'phone': u'202-224-5824',
#   u'rss_url': u'http://www.landrieu.senate.gov/rss/',
#   u'state': u'LA',
#   u'thomas_id': u'01546',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://www.landrieu.senate.gov',
#   u'votesmart_id': u'661',
#   u'washington_post_id': u'gIQAi61x9O',
#   u'wikipedia_id': u'Mary Landrieu',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fe2'),
#   u'address': u'2417 Rayburn HOB; Washington DC 20515-2306',
#   u'ballotpedia_id': u'Michele Bachmann',
#   u'bioguide_id': u'B001256',
#   u'birthday': u'1956-04-06',
#   u'contact_form': u'https://bachmann.house.gov/contact/email-michele',
#   u'cspan_id': u'1021492',
#   u'district': u'6',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Michele',
#   u'gender': u'F',
#   u'govtrack_id': u'412216',
#   u'icpsr_id': u'20728',
#   u'last_name': u'Bachmann',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027493',
#   u'party': u'Republican',
#   u'phone': u'202-225-2331',
#   u'rss_url': u'http://bachmann.house.gov/rss.xml',
#   u'state': u'MN',
#   u'thomas_id': u'01858',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://bachmann.house.gov',
#   u'votesmart_id': u'54675',
#   u'washington_post_id': u'gIQALIcw9O',
#   u'wikipedia_id': u'Michele Bachmann',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fea'),
#   u'address': u'1510 Longworth HOB; Washington DC 20515-5501',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'C000380',
#   u'birthday': u'1945-09-19',
#   u'contact_form': u'https://donnachristensen.house.gov/contact-me/email-me',
#   u'cspan_id': u'48879',
#   u'district': u'0',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Donna',
#   u'gender': u'F',
#   u'govtrack_id': u'400073',
#   u'icpsr_id': u'',
#   u'last_name': u'Christensen',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00000133',
#   u'party': u'Democrat',
#   u'phone': u'202-225-1790',
#   u'rss_url': u'http://donnachristensen.house.gov/rss.xml',
#   u'state': u'VI',
#   u'thomas_id': u'01474',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://donnachristensen.house.gov',
#   u'votesmart_id': u'1032',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Donna Christian-Christensen',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ff2'),
#   u'address': u'238 Cannon HOB; Washington DC 20515-1101',
#   u'ballotpedia_id': u'Colleen Hanabusa',
#   u'bioguide_id': u'H001050',
#   u'birthday': u'1951-05-04',
#   u'contact_form': u'https://hanabusa.house.gov/contact-me/email-me',
#   u'cspan_id': u'61258',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Colleen',
#   u'gender': u'F',
#   u'govtrack_id': u'412418',
#   u'icpsr_id': u'21124',
#   u'last_name': u'Hanabusa',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00025881',
#   u'party': u'Democrat',
#   u'phone': u'202-225-2726',
#   u'rss_url': u'http://hanabusa.house.gov/rss.xml',
#   u'state': u'HI',
#   u'thomas_id': u'02010',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://hanabusa.house.gov',
#   u'votesmart_id': u'17745',
#   u'washington_post_id': u'gIQAZLnUKP',
#   u'wikipedia_id': u'Colleen Hanabusa',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ff8'),
#   u'address': u'2346 Rayburn HOB; Washington DC 20515-3204',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M000309',
#   u'birthday': u'1944-01-05',
#   u'contact_form': u'https://carolynmccarthy.house.gov/contact',
#   u'cspan_id': u'45040',
#   u'district': u'4',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Carolyn',
#   u'gender': u'F',
#   u'govtrack_id': u'400257',
#   u'icpsr_id': u'29744',
#   u'last_name': u'McCarthy',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00001148',
#   u'party': u'Democrat',
#   u'phone': u'202-225-5516',
#   u'rss_url': u'http://www.house.gov/common/rss/?rss=155',
#   u'state': u'NY',
#   u'thomas_id': u'01503',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://carolynmccarthy.house.gov',
#   u'votesmart_id': u'693',
#   u'washington_post_id': u'gIQAiZEKAP',
#   u'wikipedia_id': u'Carolyn McCarthy',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d265005'),
#   u'address': u'1227 Longworth HOB; Washington DC 20515-3813',
#   u'ballotpedia_id': u'Allyson Schwartz',
#   u'bioguide_id': u'S001162',
#   u'birthday': u'1948-10-03',
#   u'contact_form': u'http://schwartz.house.gov/serving-you/email-me',
#   u'cspan_id': u'57332',
#   u'district': u'13',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Allyson',
#   u'gender': u'F',
#   u'govtrack_id': u'400647',
#   u'icpsr_id': u'20525',
#   u'last_name': u'Schwartz',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00001579',
#   u'party': u'Democrat',
#   u'phone': u'202-225-6111',
#   u'rss_url': u'http://schwartz.house.gov/rss.xml',
#   u'state': u'PA',
#   u'thomas_id': u'01798',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://schwartz.house.gov',
#   u'votesmart_id': u'5239',
#   u'washington_post_id': u'gIQAG8UjAP',
#   u'wikipedia_id': u'Allyson Schwartz',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d26500d'),
#   u'address': u'1530 Longworth HOB; Washington DC 20515-2901',
#   u'ballotpedia_id': u'Carol Shea-Porter',
#   u'bioguide_id': u'S001170',
#   u'birthday': u'1952-12-02',
#   u'contact_form': u'https://shea-porter.house.gov/contact/email-me',
#   u'cspan_id': u'1021773',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Carol',
#   u'gender': u'F',
#   u'govtrack_id': u'412219',
#   u'icpsr_id': u'20731',
#   u'last_name': u'Shea-Porter',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00028091',
#   u'party': u'Democrat',
#   u'phone': u'202-225-5456',
#   u'rss_url': u'http://shea-porter.house.gov/rss.xml',
#   u'state': u'NH',
#   u'thomas_id': u'01861',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://shea-porter.house.gov',
#   u'votesmart_id': u'65891',
#   u'washington_post_id': u'gIQAUxJWBP',
#   u'wikipedia_id': u'Carol Shea-Porter',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d26500f'),
#   u'address': u'1641 Longworth HOB; Washington DC 20515-0535',
#   u'ballotpedia_id': u'Gloria Negrete McLeod',
#   u'bioguide_id': u'N000187',
#   u'birthday': u'1941-09-06',
#   u'contact_form': u'http://negretemcleod.house.gov/EmailGloria',
#   u'cspan_id': u'69136',
#   u'district': u'35',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Gloria',
#   u'gender': u'F',
#   u'govtrack_id': u'412518',
#   u'icpsr_id': u'21310',
#   u'last_name': u'Negrete McLeod',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00033509',
#   u'party': u'Democrat',
#   u'phone': u'202-225-6161',
#   u'rss_url': u'http://negretemcleod.house.gov/rss.xml',
#   u'state': u'CA',
#   u'thomas_id': u'02108',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://negretemcleod.house.gov',
#   u'votesmart_id': u'16492',
#   u'washington_post_id': u'3aa86742-4bbc-11e2-8758-b64a2997a921',
#   u'wikipedia_id': u'Gloria Negrete McLeod',
#   u'youtube': u'',
#   u'youtube_id': u''}]

# %% [markdown]
# How about a list of legislators who are women, whose party is not `Democrat`?

# %%
list(coll.find({'gender': 'F', 'party': {'$ne': 'Democrat'}}))
# Out:
# [{u'_id': ObjectId('5888967810f3fc0e1d264d99'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'G000408',
#   u'birthday': u'1958-06-05',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'2',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Enid',
#   u'gender': u'F',
#   u'govtrack_id': u'411214',
#   u'icpsr_id': u'29575',
#   u'last_name': u'Greene Waldholtz',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'UT',
#   u'thomas_id': u'01192',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Enid Greene',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264de1'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'C000345',
#   u'birthday': u'1938-01-27',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Helen',
#   u'gender': u'F',
#   u'govtrack_id': u'400575',
#   u'icpsr_id': u'29514',
#   u'last_name': u'Chenoweth-Hage',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'ID',
#   u'thomas_id': u'00194',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e37'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M000941',
#   u'birthday': u'1931-02-12',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'8',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Constance',
#   u'gender': u'F',
#   u'govtrack_id': u'400524',
#   u'icpsr_id': u'15434',
#   u'last_name': u'Morella',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'MD',
#   u'thomas_id': u'00833',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e3c'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'R000465',
#   u'birthday': u'1929-09-19',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Marge',
#   u'gender': u'F',
#   u'govtrack_id': u'400533',
#   u'icpsr_id': u'14855',
#   u'last_name': u'Roukema',
#   u'lis_id': u'',
#   u'opensecrets_id': u'',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NJ',
#   u'thomas_id': u'00990',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e5d'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000601',
#   u'birthday': u'1936-07-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Elizabeth',
#   u'gender': u'F',
#   u'govtrack_id': u'300035',
#   u'icpsr_id': u'40303',
#   u'last_name': u'Dole',
#   u'lis_id': u'S292',
#   u'opensecrets_id': u'N00008071',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NC',
#   u'thomas_id': u'01698',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://dole.senate.gov/',
#   u'votesmart_id': u'41533',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e60'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000549',
#   u'birthday': u'1941-07-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'8',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jennifer',
#   u'gender': u'F',
#   u'govtrack_id': u'400117',
#   u'icpsr_id': u'39312',
#   u'last_name': u'Dunn',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00007823',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'WA',
#   u'thomas_id': u'00324',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/dunn',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jennifer Dunn',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e99'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001035',
#   u'birthday': u'1957-04-05',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'13',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Katherine',
#   u'gender': u'F',
#   u'govtrack_id': u'400167',
#   u'icpsr_id': u'20314',
#   u'last_name': u'Harris',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00024882',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'01714',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/harris',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264e9a'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001033',
#   u'birthday': u'1962-04-04',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'4',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Melissa',
#   u'gender': u'F',
#   u'govtrack_id': u'400168',
#   u'icpsr_id': u'20133',
#   u'last_name': u'Hart',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00009715',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'PA',
#   u'thomas_id': u'01666',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://hart.house.gov',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Melissa Hart (politician)',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ea1'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'J000163',
#   u'birthday': u'1935-01-05',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Nancy',
#   u'gender': u'F',
#   u'govtrack_id': u'400205',
#   u'icpsr_id': u'15028',
#   u'last_name': u'Johnson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00000561',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CT',
#   u'thomas_id': u'00602',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/nancyjohnson',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ea2'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'K000078',
#   u'birthday': u'1936-09-26',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'19',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Sue',
#   u'gender': u'F',
#   u'govtrack_id': u'400213',
#   u'icpsr_id': u'29544',
#   u'last_name': u'Kelly',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00001020',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NY',
#   u'thomas_id': u'00624',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/suekelly',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Sue W. Kelly',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264eaa'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'N000143',
#   u'birthday': u'1948-01-22',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'3',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Anne',
#   u'gender': u'F',
#   u'govtrack_id': u'400294',
#   u'icpsr_id': u'29725',
#   u'last_name': u'Northup',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00003392',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'KY',
#   u'thomas_id': u'01508',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/northup',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ec0'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'S001166',
#   u'birthday': u'1953-06-22',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'22',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Shelley',
#   u'gender': u'F',
#   u'govtrack_id': u'412185',
#   u'icpsr_id': u'20541',
#   u'last_name': u'Sekula-Gibbs',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00028489',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'TX',
#   u'thomas_id': u'01819',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'',
#   u'votesmart_id': u'',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ec9'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'C000962',
#   u'birthday': u'1946-11-30',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'0',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Barbara',
#   u'gender': u'F',
#   u'govtrack_id': u'400088',
#   u'icpsr_id': u'29584',
#   u'last_name': u'Cubin',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00006242',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'WY',
#   u'thomas_id': u'00254',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/cubin',
#   u'votesmart_id': u'22044',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Barbara Cubin',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ecb'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000597',
#   u'birthday': u'1950-06-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jo Ann',
#   u'gender': u'F',
#   u'govtrack_id': u'400095',
#   u'icpsr_id': u'20141',
#   u'last_name': u'Davis',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00013078',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'VA',
#   u'thomas_id': u'01672',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://joanndavis.house.gov',
#   u'votesmart_id': u'24970',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jo Ann Davis',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ece'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'D000605',
#   u'birthday': u'1949-11-20',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'2',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Thelma',
#   u'gender': u'F',
#   u'govtrack_id': u'400658',
#   u'icpsr_id': u'20534',
#   u'last_name': u'Drake',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027281',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'VA',
#   u'thomas_id': u'01808',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://drake.house.gov',
#   u'votesmart_id': u'8231',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Thelma Drake',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ef1'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M001152',
#   u'birthday': u'1949-01-27',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'4',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Marilyn',
#   u'gender': u'F',
#   u'govtrack_id': u'400287',
#   u'icpsr_id': u'20311',
#   u'last_name': u'Musgrave',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00025054',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'CO',
#   u'thomas_id': u'01711',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://musgrave.house.gov',
#   u'votesmart_id': u'2703',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Marilyn Musgrave',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264ef6'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'P000555',
#   u'birthday': u'1951-07-29',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'15',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Deborah',
#   u'gender': u'F',
#   u'govtrack_id': u'400327',
#   u'icpsr_id': u'29390',
#   u'last_name': u'Pryce',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00003504',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'OH',
#   u'thomas_id': u'00933',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/pryce',
#   u'votesmart_id': u'27020',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Deborah Pryce',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f03'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'W000789',
#   u'birthday': u'1960-12-30',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'1',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Heather',
#   u'gender': u'F',
#   u'govtrack_id': u'400434',
#   u'icpsr_id': u'29779',
#   u'last_name': u'Wilson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00006546',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'NM',
#   u'thomas_id': u'01539',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://wilson.house.gov',
#   u'votesmart_id': u'22687',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Heather Wilson',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f13'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001247',
#   u'birthday': u'1943-10-05',
#   u'contact_form': u'',
#   u'cspan_id': u'1003557',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Virginia',
#   u'gender': u'F',
#   u'govtrack_id': u'400051',
#   u'icpsr_id': u'20313',
#   u'last_name': u'Brown-Waite',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00024777',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'01713',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/brown-waite',
#   u'votesmart_id': u'8077',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Ginny Brown-Waite',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f24'),
#   u'address': u'',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'F000453',
#   u'birthday': u'1954-12-09',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'5',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Mary',
#   u'gender': u'F',
#   u'govtrack_id': u'412230',
#   u'icpsr_id': u'20742',
#   u'last_name': u'Fallin',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027781',
#   u'party': u'Republican',
#   u'phone': u'',
#   u'rss_url': u'',
#   u'state': u'OK',
#   u'thomas_id': u'01872',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://fallin.house.gov',
#   u'votesmart_id': u'1699',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Mary Fallin',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f7a'),
#   u'address': u'284 RUSSELL SENATE OFFICE BUILDING WASHINGTON DC 20510',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001016',
#   u'birthday': u'1943-07-22',
#   u'contact_form': u'http://www.hutchison.senate.gov/?p=email_kay',
#   u'cspan_id': u'24713',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Kay',
#   u'gender': u'F',
#   u'govtrack_id': u'300054',
#   u'icpsr_id': u'49306',
#   u'last_name': u'Hutchison',
#   u'lis_id': u'S235',
#   u'opensecrets_id': u'N00005675',
#   u'party': u'Republican',
#   u'phone': u'202-224-5922',
#   u'rss_url': u'',
#   u'state': u'TX',
#   u'thomas_id': u'01368',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://hutchison.senate.gov/',
#   u'votesmart_id': u'53349',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Kay Bailey Hutchison',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f80'),
#   u'address': u'154 RUSSELL SENATE OFFICE BUILDING WASHINGTON DC 20510',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'S000663',
#   u'birthday': u'1947-02-21',
#   u'contact_form': u'http://www.snowe.senate.gov/public/index.cfm/contact?p=email',
#   u'cspan_id': u'',
#   u'district': u'',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Olympia',
#   u'gender': u'F',
#   u'govtrack_id': u'300091',
#   u'icpsr_id': u'14661',
#   u'last_name': u'Snowe',
#   u'lis_id': u'S245',
#   u'opensecrets_id': u'N00000480',
#   u'party': u'Republican',
#   u'phone': u'202-224-5344',
#   u'rss_url': u'',
#   u'state': u'ME',
#   u'thomas_id': u'01085',
#   u'twitter': u'',
#   u'type': u'sen',
#   u'url': u'http://snowe.senate.gov/',
#   u'votesmart_id': u'26885',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f84'),
#   u'address': u'216 Cannon HOB; Washington DC 20515-0924',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'A000366',
#   u'birthday': u'1956-12-14',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'24',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Sandy',
#   u'gender': u'F',
#   u'govtrack_id': u'412414',
#   u'icpsr_id': u'21120',
#   u'last_name': u'Adams',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00030926',
#   u'party': u'Republican',
#   u'phone': u'202-225-2706',
#   u'rss_url': u'',
#   u'state': u'FL',
#   u'thomas_id': u'02006',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://adams.house.gov/',
#   u'votesmart_id': u'31041',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Sandy Adams',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f8e'),
#   u'address': u'2113 Rayburn HOB; Washington DC 20515-1313',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001232',
#   u'birthday': u'1937-08-15',
#   u'contact_form': u'http://judybiggert.house.gov/ContactJudy.aspx',
#   u'cspan_id': u'57890',
#   u'district': u'13',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Judy',
#   u'gender': u'F',
#   u'govtrack_id': u'400027',
#   u'icpsr_id': u'29912',
#   u'last_name': u'Biggert',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00004762',
#   u'party': u'Republican',
#   u'phone': u'202-225-3515',
#   u'rss_url': u'',
#   u'state': u'IL',
#   u'thomas_id': u'01577',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://judybiggert.house.gov',
#   u'votesmart_id': u'6298',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Judy Biggert',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f90'),
#   u'address': u'104 Cannon HOB; Washington DC 20515-0545',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001228',
#   u'birthday': u'1961-10-24',
#   u'contact_form': u'http://www.house.gov/formbono/issue.htm',
#   u'cspan_id': u'',
#   u'district': u'45',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Mary',
#   u'gender': u'F',
#   u'govtrack_id': u'400039',
#   u'icpsr_id': u'29775',
#   u'last_name': u'Bono Mack',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00007068',
#   u'party': u'Republican',
#   u'phone': u'202-225-5330',
#   u'rss_url': u'',
#   u'state': u'CA',
#   u'thomas_id': u'01465',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://bono.house.gov',
#   u'votesmart_id': u'1434',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264f93'),
#   u'address': u'1630 Longworth HOB; Washington DC 20515-3225',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'B001276',
#   u'birthday': u'1951-05-08',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'25',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Ann Marie',
#   u'gender': u'F',
#   u'govtrack_id': u'412456',
#   u'icpsr_id': u'21158',
#   u'last_name': u'Buerkle',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00031640',
#   u'party': u'Republican',
#   u'phone': u'202-225-3701',
#   u'rss_url': u'',
#   u'state': u'NY',
#   u'thomas_id': u'02045',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://buerkle.house.gov/',
#   u'votesmart_id': u'127047',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Ann Marie Buerkle',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fa1'),
#   u'address': u'1440 Longworth HOB; Washington DC 20515-3219',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'H001054',
#   u'birthday': u'1959-12-14',
#   u'contact_form': u'',
#   u'cspan_id': u'',
#   u'district': u'19',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Nan',
#   u'gender': u'F',
#   u'govtrack_id': u'412452',
#   u'icpsr_id': u'21155',
#   u'last_name': u'Hayworth',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00031124',
#   u'party': u'Republican',
#   u'phone': u'202-225-5441',
#   u'rss_url': u'',
#   u'state': u'NY',
#   u'thomas_id': u'02042',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://hayworth.house.gov/',
#   u'votesmart_id': u'127041',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Nan Hayworth',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fb0'),
#   u'address': u'230 Cannon HOB; Washington DC 20515-3309',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'M001134',
#   u'birthday': u'1941-08-01',
#   u'contact_form': u'http://myrick.house.gov/zipauth.shtml',
#   u'cspan_id': u'1172',
#   u'district': u'9',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Sue',
#   u'gender': u'F',
#   u'govtrack_id': u'400288',
#   u'icpsr_id': u'29549',
#   u'last_name': u'Myrick',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00002327',
#   u'party': u'Republican',
#   u'phone': u'202-225-1976',
#   u'rss_url': u'',
#   u'state': u'NC',
#   u'thomas_id': u'00849',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/myrick',
#   u'votesmart_id': u'21789',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Sue Myrick',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fbd'),
#   u'address': u'2464 Rayburn HOB; Washington DC 20515-3502',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'S001164',
#   u'birthday': u'1951-11-29',
#   u'contact_form': u'http://www.house.gov/schmidt/contact.shtml',
#   u'cspan_id': u'1017087',
#   u'district': u'2',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jean',
#   u'gender': u'F',
#   u'govtrack_id': u'412010',
#   u'icpsr_id': u'20540',
#   u'last_name': u'Schmidt',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027526',
#   u'party': u'Republican',
#   u'phone': u'202-225-3164',
#   u'rss_url': u'',
#   u'state': u'OH',
#   u'thomas_id': u'01815',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://www.house.gov/schmidt',
#   u'votesmart_id': u'45475',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jean Schmidt',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fcb'),
#   u'address': u'2230 Rayburn HOB; Washington DC 20515-2508',
#   u'ballotpedia_id': u'',
#   u'bioguide_id': u'E000172',
#   u'birthday': u'1950-09-16',
#   u'contact_form': u'http://www.house.gov/emerson/contact/',
#   u'cspan_id': u'46627',
#   u'district': u'8',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Jo Ann',
#   u'gender': u'F',
#   u'govtrack_id': u'400121',
#   u'icpsr_id': u'29736',
#   u'last_name': u'Emerson',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00005090',
#   u'party': u'Republican',
#   u'phone': u'202-225-4404',
#   u'rss_url': u'',
#   u'state': u'MO',
#   u'thomas_id': u'01481',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://emerson.house.gov',
#   u'votesmart_id': u'903',
#   u'washington_post_id': u'',
#   u'wikipedia_id': u'Jo Ann Emerson',
#   u'youtube': u'',
#   u'youtube_id': u''},
#  {u'_id': ObjectId('5888967810f3fc0e1d264fe2'),
#   u'address': u'2417 Rayburn HOB; Washington DC 20515-2306',
#   u'ballotpedia_id': u'Michele Bachmann',
#   u'bioguide_id': u'B001256',
#   u'birthday': u'1956-04-06',
#   u'contact_form': u'https://bachmann.house.gov/contact/email-michele',
#   u'cspan_id': u'1021492',
#   u'district': u'6',
#   u'facebook': u'',
#   u'facebook_id': u'',
#   u'first_name': u'Michele',
#   u'gender': u'F',
#   u'govtrack_id': u'412216',
#   u'icpsr_id': u'20728',
#   u'last_name': u'Bachmann',
#   u'lis_id': u'',
#   u'opensecrets_id': u'N00027493',
#   u'party': u'Republican',
#   u'phone': u'202-225-2331',
#   u'rss_url': u'http://bachmann.house.gov/rss.xml',
#   u'state': u'MN',
#   u'thomas_id': u'01858',
#   u'twitter': u'',
#   u'type': u'rep',
#   u'url': u'http://bachmann.house.gov',
#   u'votesmart_id': u'54675',
#   u'washington_post_id': u'gIQALIcw9O',
#   u'wikipedia_id': u'Michele Bachmann',
#   u'youtube': u'',
#   u'youtube_id': u''}]

# %% [markdown]
# Make a list of these women, including only their names, states, and birthdays:

# %%
list(coll.find(
        {'gender': 'F', 'party': {'$ne': 'Democrat'}}, 
        {'first_name': 1, 'last_name': 1, 'state': 1, 'birthday': 1, '_id': 0}))
# Out:
# [{u'birthday': u'1958-06-05',
#   u'first_name': u'Enid',
#   u'last_name': u'Greene Waldholtz',
#   u'state': u'UT'},
#  {u'birthday': u'1938-01-27',
#   u'first_name': u'Helen',
#   u'last_name': u'Chenoweth-Hage',
#   u'state': u'ID'},
#  {u'birthday': u'1931-02-12',
#   u'first_name': u'Constance',
#   u'last_name': u'Morella',
#   u'state': u'MD'},
#  {u'birthday': u'1929-09-19',
#   u'first_name': u'Marge',
#   u'last_name': u'Roukema',
#   u'state': u'NJ'},
#  {u'birthday': u'1936-07-29',
#   u'first_name': u'Elizabeth',
#   u'last_name': u'Dole',
#   u'state': u'NC'},
#  {u'birthday': u'1941-07-29',
#   u'first_name': u'Jennifer',
#   u'last_name': u'Dunn',
#   u'state': u'WA'},
#  {u'birthday': u'1957-04-05',
#   u'first_name': u'Katherine',
#   u'last_name': u'Harris',
#   u'state': u'FL'},
#  {u'birthday': u'1962-04-04',
#   u'first_name': u'Melissa',
#   u'last_name': u'Hart',
#   u'state': u'PA'},
#  {u'birthday': u'1935-01-05',
#   u'first_name': u'Nancy',
#   u'last_name': u'Johnson',
#   u'state': u'CT'},
#  {u'birthday': u'1936-09-26',
#   u'first_name': u'Sue',
#   u'last_name': u'Kelly',
#   u'state': u'NY'},
#  {u'birthday': u'1948-01-22',
#   u'first_name': u'Anne',
#   u'last_name': u'Northup',
#   u'state': u'KY'},
#  {u'birthday': u'1953-06-22',
#   u'first_name': u'Shelley',
#   u'last_name': u'Sekula-Gibbs',
#   u'state': u'TX'},
#  {u'birthday': u'1946-11-30',
#   u'first_name': u'Barbara',
#   u'last_name': u'Cubin',
#   u'state': u'WY'},
#  {u'birthday': u'1950-06-29',
#   u'first_name': u'Jo Ann',
#   u'last_name': u'Davis',
#   u'state': u'VA'},
#  {u'birthday': u'1949-11-20',
#   u'first_name': u'Thelma',
#   u'last_name': u'Drake',
#   u'state': u'VA'},
#  {u'birthday': u'1949-01-27',
#   u'first_name': u'Marilyn',
#   u'last_name': u'Musgrave',
#   u'state': u'CO'},
#  {u'birthday': u'1951-07-29',
#   u'first_name': u'Deborah',
#   u'last_name': u'Pryce',
#   u'state': u'OH'},
#  {u'birthday': u'1960-12-30',
#   u'first_name': u'Heather',
#   u'last_name': u'Wilson',
#   u'state': u'NM'},
#  {u'birthday': u'1943-10-05',
#   u'first_name': u'Virginia',
#   u'last_name': u'Brown-Waite',
#   u'state': u'FL'},
#  {u'birthday': u'1954-12-09',
#   u'first_name': u'Mary',
#   u'last_name': u'Fallin',
#   u'state': u'OK'},
#  {u'birthday': u'1943-07-22',
#   u'first_name': u'Kay',
#   u'last_name': u'Hutchison',
#   u'state': u'TX'},
#  {u'birthday': u'1947-02-21',
#   u'first_name': u'Olympia',
#   u'last_name': u'Snowe',
#   u'state': u'ME'},
#  {u'birthday': u'1956-12-14',
#   u'first_name': u'Sandy',
#   u'last_name': u'Adams',
#   u'state': u'FL'},
#  {u'birthday': u'1937-08-15',
#   u'first_name': u'Judy',
#   u'last_name': u'Biggert',
#   u'state': u'IL'},
#  {u'birthday': u'1961-10-24',
#   u'first_name': u'Mary',
#   u'last_name': u'Bono Mack',
#   u'state': u'CA'},
#  {u'birthday': u'1951-05-08',
#   u'first_name': u'Ann Marie',
#   u'last_name': u'Buerkle',
#   u'state': u'NY'},
#  {u'birthday': u'1959-12-14',
#   u'first_name': u'Nan',
#   u'last_name': u'Hayworth',
#   u'state': u'NY'},
#  {u'birthday': u'1941-08-01',
#   u'first_name': u'Sue',
#   u'last_name': u'Myrick',
#   u'state': u'NC'},
#  {u'birthday': u'1951-11-29',
#   u'first_name': u'Jean',
#   u'last_name': u'Schmidt',
#   u'state': u'OH'},
#  {u'birthday': u'1950-09-16',
#   u'first_name': u'Jo Ann',
#   u'last_name': u'Emerson',
#   u'state': u'MO'},
#  {u'birthday': u'1956-04-06',
#   u'first_name': u'Michele',
#   u'last_name': u'Bachmann',
#   u'state': u'MN'}]

# %% [markdown]
# List the youngest five Republican legislators, as determined by their birthday:

# %%
list(coll.find(
        {'party': 'Republican'},
        {'first_name': 1, 'last_name': 1, 'birthday': 1, 'state': 1, '_id': 0}
    ).sort('birthday', -1).limit(5))
# Out:
# [{u'birthday': u'1976-11-03',
#   u'first_name': u'Ben',
#   u'last_name': u'Quayle',
#   u'state': u'AZ'},
#  {u'birthday': u'1976-04-20',
#   u'first_name': u'Trey',
#   u'last_name': u'Radel',
#   u'state': u'FL'},
#  {u'birthday': u'1974-07-31',
#   u'first_name': u'Adam',
#   u'last_name': u'Putnam',
#   u'state': u'FL'},
#  {u'birthday': u'1974-01-07',
#   u'first_name': u'Vance',
#   u'last_name': u'McAllister',
#   u'state': u'LA'},
#  {u'birthday': u'1973-11-27',
#   u'first_name': u'Jon',
#   u'last_name': u'Runyan',
#   u'state': u'NJ'}]

# %% [markdown]
# Make a list of all distinct parties? (Witness the variety of American democracy)

# %%
coll.distinct('party')
# Out:
# [u'Anti-Administration',
#  u'',
#  u'Pro-Administration',
#  u'Republican',
#  u'Federalist',
#  u'Democratic Republican',
#  u'Unknown',
#  u'Adams',
#  u'Jackson',
#  u'Jackson Republican',
#  u'Crawford Republican',
#  u'Whig',
#  u'Anti-Jacksonian',
#  u'Adams Democrat',
#  u'Nullifier',
#  u'Anti Masonic',
#  u'Anti Jacksonian',
#  u'Jacksonian',
#  u'Democrat',
#  u'Anti Jackson',
#  u'Union Democrat',
#  u'Conservative',
#  u'Ind. Democrat',
#  u'Law and Order',
#  u'American',
#  u'Liberty',
#  u'Free Soil',
#  u'Independent',
#  u'Ind. Republican-Democrat',
#  u'Ind. Whig',
#  u'Unionist',
#  u'States Rights',
#  u'Anti-Lecompton Democrat',
#  u'Constitutional Unionist',
#  u'Independent Democrat',
#  u'Unconditional Unionist',
#  u'Conservative Republican',
#  u'Ind. Republican',
#  u'Liberal Republican',
#  u'National Greenbacker',
#  u'Readjuster Democrat',
#  u'Readjuster',
#  u'Union',
#  u'Union Labor',
#  u'Populist',
#  u'Silver Republican',
#  u'Free Silver',
#  u'Democratic and Union Labor',
#  u'Progressive Republican',
#  u'Progressive',
#  u'Prohibitionist',
#  u'Socialist',
#  u'Farmer-Labor',
#  u'Nonpartisan',
#  u'Coalitionist',
#  u'Popular Democrat',
#  u'American Labor',
#  u'New Progressive',
#  u'Republican-Conservative',
#  u'Democrat-Liberal']

# %% [markdown]
# Read the documentation for [MongoDB's `$nin` operator](http://docs.mongodb.org/manual/reference/operator/query/nin/), and write a MongoDB query that returns a list of the names, states, and parties of all legislators whose party is neither Republican nor Democrat.

# %%
list(coll.find(
        {'party': {'$nin': ['Republican', 'Democrat']}},
        {'first_name': 1, 'last_name': 1, 'state': 1, 'party': 1, '_id': 0}))
# Out:
# [{u'first_name': u'Richard',
#   u'last_name': u'Bassett',
#   u'party': u'Anti-Administration',
#   u'state': u'DE'},
#  {u'first_name': u'Theodorick',
#   u'last_name': u'Bland',
#   u'party': u'',
#   u'state': u'VA'},
#  {u'first_name': u'Aedanus',
#   u'last_name': u'Burke',
#   u'party': u'',
#   u'state': u'SC'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Carroll',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'George',
#   u'last_name': u'Clymer',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Contee',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Tristram',
#   u'last_name': u'Dalton',
#   u'party': u'Pro-Administration',
#   u'state': u'MA'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Elmer',
#   u'party': u'Pro-Administration',
#   u'state': u'NJ'},
#  {u'first_name': u'William',
#   u'last_name': u'Few',
#   u'party': u'Anti-Administration',
#   u'state': u'GA'},
#  {u'first_name': u'William',
#   u'last_name': u'Floyd',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'George',
#   u'last_name': u'Gale',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'William',
#   u'last_name': u'Grayson',
#   u'party': u'Anti-Administration',
#   u'state': u'VA'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Grout',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Hawkins',
#   u'party': u'Pro-Administration',
#   u'state': u'NC'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Huntington',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'Ralph',
#   u'last_name': u'Izard',
#   u'party': u'Pro-Administration',
#   u'state': u'SC'},
#  {u'first_name': u'William',
#   u'last_name': u'Johnson',
#   u'party': u'Pro-Administration',
#   u'state': u'CT'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Johnston',
#   u'party': u'Pro-Administration',
#   u'state': u'NC'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Lee',
#   u'party': u'Anti-Administration',
#   u'state': u'VA'},
#  {u'first_name': u'William',
#   u'last_name': u'Maclay',
#   u'party': u'Anti-Administration',
#   u'state': u'PA'},
#  {u'first_name': u'George',
#   u'last_name': u'Mathews',
#   u'party': u'',
#   u'state': u'GA'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Morris',
#   u'party': u'Pro-Administration',
#   u'state': u'PA'},
#  {u'first_name': u'George',
#   u'last_name': u'Partridge',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Paterson',
#   u'party': u'Pro-Administration',
#   u'state': u'NJ'},
#  {u'first_name': u'William',
#   u'last_name': u'Smith',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Michael',
#   u'last_name': u'Stone',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Jeremiah',
#   u'last_name': u'Van Rensselaer',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Wynkoop',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Philemon',
#   u'last_name': u'Dickinson',
#   u'party': u'Pro-Administration',
#   u'state': u'NJ'},
#  {u'first_name': u'John',
#   u'last_name': u'Walker',
#   u'party': u'Pro-Administration',
#   u'state': u'VA'},
#  {u'first_name': u'John',
#   u'last_name': u'Ashe',
#   u'party': u'',
#   u'state': u'NC'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Barnwell',
#   u'party': u'',
#   u'state': u'SC'},
#  {u'first_name': u'George',
#   u'last_name': u'Cabot',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Carroll',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Oliver',
#   u'last_name': u'Ellsworth',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Elbridge',
#   u'last_name': u'Gerry',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Huger',
#   u'party': u'',
#   u'state': u'SC'},
#  {u'first_name': u'Israel',
#   u'last_name': u'Jacobs',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Philip',
#   u'last_name': u'Key',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'George',
#   u'last_name': u'Read',
#   u'party': u'',
#   u'state': u'DE'},
#  {u'first_name': u'Moses',
#   u'last_name': u'Robinson',
#   u'party': u'Anti-Administration',
#   u'state': u'VT'},
#  {u'first_name': u'Cornelius',
#   u'last_name': u'Schoonmaker',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Joshua',
#   u'last_name': u'Seney',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Upton',
#   u'last_name': u'Sheredine',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Roger',
#   u'last_name': u'Sherman',
#   u'party': u'Pro-Administration',
#   u'state': u'CT'},
#  {u'first_name': u'Peter',
#   u'last_name': u'Silvester',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Steele',
#   u'party': u'',
#   u'state': u'NC'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Sterett',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Sturges',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Tucker',
#   u'party': u'',
#   u'state': u'SC'},
#  {u'first_name': u'Anthony',
#   u'last_name': u'Wayne',
#   u'party': u'',
#   u'state': u'GA'},
#  {u'first_name': u'Alexander',
#   u'last_name': u'White',
#   u'party': u'',
#   u'state': u'VA'},
#  {u'first_name': u'Hugh',
#   u'last_name': u'Williamson',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Francis',
#   u'last_name': u'Willis',
#   u'party': u'',
#   u'state': u'GA'},
#  {u'first_name': u'John',
#   u'last_name': u'Edwards',
#   u'party': u'Anti-Administration',
#   u'state': u'KY'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Potts',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'James',
#   u'last_name': u'Armstrong',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'John',
#   u'last_name': u'Beatty',
#   u'party': u'',
#   u'state': u'NJ'},
#  {u'first_name': u'Elias',
#   u'last_name': u'Boudinot',
#   u'party': u'',
#   u'state': u'NJ'},
#  {u'first_name': u'Shearjashub',
#   u'last_name': u'Bourne',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Bradford',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'Lambert',
#   u'last_name': u'Cadwalader',
#   u'party': u'',
#   u'state': u'NJ'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Carnes',
#   u'party': u'',
#   u'state': u'GA'},
#  {u'first_name': u'Abraham',
#   u'last_name': u'Clark',
#   u'party': u'',
#   u'state': u'NJ'},
#  {u'first_name': u'David',
#   u'last_name': u'Cobb',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'Peleg',
#   u'last_name': u'Coffin',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Dawson',
#   u'party': u'Anti-Administration',
#   u'state': u'NC'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Edwards',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Fitzsimons',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Uriah',
#   u'last_name': u'Forrest',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Frederick',
#   u'last_name': u'Frelinghuysen',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'Alexander',
#   u'last_name': u'Gillon',
#   u'party': u'',
#   u'state': u'SC'},
#  {u'first_name': u'James',
#   u'last_name': u'Gordon',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Griffin',
#   u'party': u'',
#   u'state': u'VA'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Holten',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Irvine',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Amasa',
#   u'last_name': u'Learned',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Lee',
#   u'party': u'',
#   u'state': u'VA'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'McDowell',
#   u'party': u'',
#   u'state': u'NC'},
#  {u'first_name': u'Alexander',
#   u'last_name': u'Mebane',
#   u'party': u'',
#   u'state': u'NC'},
#  {u'first_name': u'John',
#   u'last_name': u'Mercer',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Stephen',
#   u'last_name': u'Mitchell',
#   u'party': u'Pro-Administration',
#   u'state': u'CT'},
#  {u'first_name': u'William',
#   u'last_name': u'Montgomery',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Neville',
#   u'party': u'',
#   u'state': u'VA'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Niles',
#   u'party': u'',
#   u'state': u'VT'},
#  {u'first_name': u'Andrew',
#   u'last_name': u'Pickens',
#   u'party': u'',
#   u'state': u'SC'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Scott',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Caleb',
#   u'last_name': u'Strong',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Silas',
#   u'last_name': u'Talbot',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Tredwell',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Peter',
#   u'last_name': u'Van Gaasbeck',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Vining',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'Jeremiah',
#   u'last_name': u'Wadsworth',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'Francis',
#   u'last_name': u'Walker',
#   u'party': u'',
#   u'state': u'VA'},
#  {u'first_name': u'Artemas',
#   u'last_name': u'Ward',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'John',
#   u'last_name': u'Watts',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Williams',
#   u'party': u'',
#   u'state': u'NC'},
#  {u'first_name': u'Paine',
#   u'last_name': u'Wingate',
#   u'party': u'',
#   u'state': u'NH'},
#  {u'first_name': u'George',
#   u'last_name': u'Walton',
#   u'party': u'Federalist',
#   u'state': u'GA'},
#  {u'first_name': u'Fisher',
#   u'last_name': u'Ames',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Bingham',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Bourne',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Buck',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Jeremiah',
#   u'last_name': u'Crabb',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Ezekiel',
#   u'last_name': u'Gilbert',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'James',
#   u'last_name': u'Gunn',
#   u'party': u'Federalist',
#   u'state': u'GA'},
#  {u'first_name': u'George',
#   u'last_name': u'Hancock',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Henderson',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'John',
#   u'last_name': u'Henry',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'George',
#   u'last_name': u'Leonard',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Humphrey',
#   u'last_name': u'Marshall',
#   u'party': u'Federalist',
#   u'state': u'KY'},
#  {u'first_name': u'William',
#   u'last_name': u'Murray',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Elijah',
#   u'last_name': u'Paine',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Jacob',
#   u'last_name': u'Read',
#   u'party': u'Federalist',
#   u'state': u'SC'},
#  {u'first_name': u'Isaac',
#   u'last_name': u'Smith',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'William',
#   u'last_name': u'Strudwick',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Zephaniah',
#   u'last_name': u'Swift',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Trumbull',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'James',
#   u'last_name': u'White',
#   u'party': u'',
#   u'state': u'TN'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Goodhue',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'John',
#   u'last_name': u'Howard',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'John',
#   u'last_name': u'Laurance',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Allen',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Theophilus',
#   u'last_name': u'Bradbury',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'David',
#   u'last_name': u'Brooks',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Stephen',
#   u'last_name': u'Bullock',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'John',
#   u'last_name': u'Chapman',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Chipman',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'James',
#   u'last_name': u'Cochran',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Joshua',
#   u'last_name': u'Coit',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'James',
#   u'last_name': u'Davenport',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'George',
#   u'last_name': u'Ege',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Hezekiah',
#   u'last_name': u'Hosmer',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Latimer',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'James',
#   u'last_name': u'Lloyd',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'James',
#   u'last_name': u'Machir',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'William',
#   u'last_name': u'Matthews',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Morgan',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Isaac',
#   u'last_name': u'Parker',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'James',
#   u'last_name': u'Ross',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'John',
#   u'last_name': u'Rutherfurd',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'Philip',
#   u'last_name': u'Schuyler',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Sinnickson',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Sitgreaves',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Jeremiah',
#   u'last_name': u'Smith',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Smith',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'William',
#   u'last_name': u'Smith',
#   u'party': u'Federalist',
#   u'state': u'SC'},
#  {u'first_name': u'Peleg',
#   u'last_name': u'Sprague',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Mark',
#   u'last_name': u'Thomson',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'John',
#   u'last_name': u'Van Alen',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Williams',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Joshua',
#   u'last_name': u'Clayton',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'John',
#   u'last_name': u'Hobart',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'William',
#   u'last_name': u'North',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'James',
#   u'last_name': u'Watson',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Bailey',
#   u'last_name': u'Bartlett',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Brace',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'John',
#   u'last_name': u'Brown',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'William',
#   u'last_name': u'Cooper',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'William',
#   u'last_name': u'Craik',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Franklin',
#   u'last_name': u'Davenport',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Dayton',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'George',
#   u'last_name': u'Dent',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Dexter',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Dickson',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'William',
#   u'last_name': u'Edmond',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Evans',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Freeman',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Glen',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Elizur',
#   u'last_name': u'Goodrich',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'William',
#   u'last_name': u'Gordon',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Ray',
#   u'last_name': u'Greene',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Hartley',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'James',
#   u'last_name': u'Imlay',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'James',
#   u'last_name': u'Jones',
#   u'party': u'Federalist',
#   u'state': u'GA'},
#  {u'first_name': u'John',
#   u'last_name': u'Kittera',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Lee',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Livermore',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Lyman',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'John',
#   u'last_name': u'Marshall',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'William',
#   u'last_name': u'McMillan',
#   u'party': u'',
#   u'state': u'OH'},
#  {u'first_name': u'Abraham',
#   u'last_name': u'Nott',
#   u'party': u'Federalist',
#   u'state': u'SC'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Page',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Josiah',
#   u'last_name': u'Parker',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Pinckney',
#   u'party': u'Federalist',
#   u'state': u'SC'},
#  {u'first_name': u'Jonas',
#   u'last_name': u'Platt',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Leven',
#   u'last_name': u'Powell',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'John',
#   u'last_name': u'Reed',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Theodore',
#   u'last_name': u'Sedgwick',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Sewall',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'George',
#   u'last_name': u'Thatcher',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'John',
#   u'last_name': u'Thomas',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Thomas',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Waln',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Dwight',
#   u'last_name': u'Foster',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Hindman',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Gouverneur',
#   u'last_name': u'Morris',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Bird',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Boude',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Paul',
#   u'last_name': u'Fearing',
#   u'party': u'Federalist',
#   u'state': u'OH'},
#  {u'first_name': u'Abiel',
#   u'last_name': u'Foster',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Greene',
#   u'party': u'',
#   u'state': u'MS'},
#  {u'first_name': u'William',
#   u'last_name': u'Grove',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Archibald',
#   u'last_name': u'Henderson',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'William',
#   u'last_name': u'Hill',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Narsworthy',
#   u'last_name': u'Hunter',
#   u'party': u'',
#   u'state': u'MS'},
#  {u'first_name': u'Silas',
#   u'last_name': u'Lee',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Ebenezer',
#   u'last_name': u'Mattoon',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Lewis',
#   u'last_name': u'Morris',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Morris',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Muhlenberg',
#   u'party': u'Democratic Republican',
#   u'state': u'PA'},
#  {u'first_name': u'Aaron',
#   u'last_name': u'Ogden',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'Simeon',
#   u'last_name': u'Olcott',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Peirce',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Elias',
#   u'last_name': u'Perkins',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Nathan',
#   u'last_name': u'Read',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'John',
#   u'last_name': u'Rutledge',
#   u'party': u'Federalist',
#   u'state': u'SC'},
#  {u'first_name': u'James',
#   u'last_name': u'Sheafe',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'William',
#   u'last_name': u'Shepard',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'John',
#   u'last_name': u'Stratton',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Uriah',
#   u'last_name': u'Tracy',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'George',
#   u'last_name': u'Upham',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Walker',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Woods',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'William',
#   u'last_name': u'Plumer',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Simeon',
#   u'last_name': u'Baldwin',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Phineas',
#   u'last_name': u'Bruce',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Manasseh',
#   u'last_name': u'Cutler',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'John',
#   u'last_name': u'Dennis',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Dwight',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Griffin',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Gaylord',
#   u'last_name': u'Griswold',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Hunt',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Lewis',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Lowndes',
#   u'party': u'Federalist',
#   u'state': u'SC'},
#  {u'first_name': u'Nahum',
#   u'last_name': u'Mitchell',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Plater',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Purviance',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Thatcher',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'George',
#   u'last_name': u'Tibbits',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'White',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'Lemuel',
#   u'last_name': u'Williams',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Silas',
#   u'last_name': u'Betton',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Theodore',
#   u'last_name': u'Dwight',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Caleb',
#   u'last_name': u'Ellis',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Calvin',
#   u'last_name': u'Goddard',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Roger',
#   u'last_name': u'Griswold',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Seth',
#   u'last_name': u'Hastings',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'David',
#   u'last_name': u'Hough',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Livingston',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Smith',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Tenney',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Peleg',
#   u'last_name': u'Wadsworth',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'James',
#   u'last_name': u'Broom',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Clark',
#   u'party': u'',
#   u'state': u'OL'},
#  {u'first_name': u'James',
#   u'last_name': u'Elliott',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Chauncey',
#   u'last_name': u'Goodrich',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'James',
#   u'last_name': u'Kelly',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Parke',
#   u'party': u'',
#   u'state': u'IN'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Allen',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Blaisdell',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'John',
#   u'last_name': u'Campbell',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'John',
#   u'last_name': u'Chamberlain',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'William',
#   u'last_name': u'Chamberlain',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Christopher',
#   u'last_name': u'Champlin',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'William',
#   u'last_name': u'Denning',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Barent',
#   u'last_name': u'Gardenier',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Haven',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'James',
#   u'last_name': u'Hillhouse',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Hubbard',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Jenkins',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Herman',
#   u'last_name': u'Knickerbocker',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Edward',
#   u'last_name': u'Livermore',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Francis',
#   u'last_name': u'Malbone',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'Vincent',
#   u'last_name': u'Mathews',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Pickman',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Julien',
#   u'last_name': u'Poydras',
#   u'party': u'',
#   u'state': u'OL'},
#  {u'first_name': u'John',
#   u'last_name': u'Stanly',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'William',
#   u'last_name': u'Stedman',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Jacob',
#   u'last_name': u'Swoope',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Jabez',
#   u'last_name': u'Upham',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Killian',
#   u'last_name': u'Van Rensselaer',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'James',
#   u'last_name': u'Wilson',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'John',
#   u'last_name': u'Baker',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'James',
#   u'last_name': u'Bayard',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'Harmanus',
#   u'last_name': u'Bleecker',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Martin',
#   u'last_name': u'Chittenden',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'James',
#   u'last_name': u'Emott',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Asa',
#   u'last_name': u'Fitch',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Philip',
#   u'last_name': u'Key',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Livingston',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Archibald',
#   u'last_name': u'McBryde',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'James',
#   u'last_name': u'Milnor',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Josiah',
#   u'last_name': u'Quincy',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'George',
#   u'last_name': u'Sullivan',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Leonard',
#   u'last_name': u'White',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Wilson',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Jean',
#   u'last_name': u'Destr\xe9han',
#   u'party': u'Unknown',
#   u'state': u'LA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Bayly',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Egbert',
#   u'last_name': u'Benson',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Abijah',
#   u'last_name': u'Bigelow',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Shadrack',
#   u'last_name': u'Bond',
#   u'party': u'',
#   u'state': u'IL'},
#  {u'first_name': u'John',
#   u'last_name': u'Bowers',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Alexander',
#   u'last_name': u'Boyd',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Hugh',
#   u'last_name': u'Caperton',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'William',
#   u'last_name': u'Coxe',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'David',
#   u'last_name': u'Daggett',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Davis',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Dewey',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Ely',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'James',
#   u'last_name': u'Geddes',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Gloninger',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Edward',
#   u'last_name': u'Hempstead',
#   u'party': u'',
#   u'state': u'MO'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Henderson',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Hopkins',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Howell',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Jacob',
#   u'last_name': u'Hufty',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Jackson',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'Jacob',
#   u'last_name': u'Markell',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Jeremiah',
#   u'last_name': u'Mason',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Morris',
#   u'last_name': u'Miller',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Pearson',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Jotham',
#   u'last_name': u'Post',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Elisha',
#   u'last_name': u'Potter',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'William',
#   u'last_name': u'Reed',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'James',
#   u'last_name': u'Schureman',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Sherwood',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Zebulon',
#   u'last_name': u'Shipherd',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Amos',
#   u'last_name': u'Slaymaker',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Smith',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Stockton',
#   u'party': u'Federalist',
#   u'state': u'NJ'},
#  {u'first_name': u'Joel',
#   u'last_name': u'Thompson',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'William',
#   u'last_name': u'Wells',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'Francis',
#   u'last_name': u'White',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Elisha',
#   u'last_name': u'Winter',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Francis',
#   u'last_name': u'Locke',
#   u'party': u'Unknown',
#   u'state': u'NC'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Thompson',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Atherton',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'George',
#   u'last_name': u'Baer',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'George',
#   u'last_name': u'Bradbury',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'James',
#   u'last_name': u'Breckinridge',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Elijah',
#   u'last_name': u'Brigham',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Brown',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Cady',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'James',
#   u'last_name': u'Carr',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Epaphroditus',
#   u'last_name': u'Champion',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Chipman',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Bradbury',
#   u'last_name': u'Cilley',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Cooper',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Dana',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'John',
#   u'last_name': u'Davenport',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Rufus',
#   u'last_name': u'Easton',
#   u'party': u'',
#   u'state': u'MO'},
#  {u'first_name': u'Amos',
#   u'last_name': u'Ellmaker',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'William',
#   u'last_name': u'Gaston',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Gold',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Goldsborough',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Christopher',
#   u'last_name': u'Gore',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Grosvenor',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'William',
#   u'last_name': u'Hale',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Outerbridge',
#   u'last_name': u'Horsey',
#   u'party': u'Federalist',
#   u'state': u'DE'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Huger',
#   u'party': u'Federalist',
#   u'state': u'SC'},
#  {u'first_name': u'John',
#   u'last_name': u'Hulbert',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Hunter',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'Luther',
#   u'last_name': u'Jewett',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Moss',
#   u'last_name': u'Kent',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Cyrus',
#   u'last_name': u'King',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Chauncey',
#   u'last_name': u'Langdon',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'William',
#   u'last_name': u'Lattimore',
#   u'party': u'',
#   u'state': u'MS'},
#  {u'first_name': u'Lyman',
#   u'last_name': u'Law',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Lewis',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'John',
#   u'last_name': u'Lovett',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Asa',
#   u'last_name': u'Lyon',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Marsh',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Hosea',
#   u'last_name': u'Moffitt',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Noyes',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Timothy',
#   u'last_name': u'Pickering',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Sheffey',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Smith',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'William',
#   u'last_name': u'Smith',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Asahel',
#   u'last_name': u'Stearns',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Stephenson',
#   u'party': u'',
#   u'state': u'IL'},
#  {u'first_name': u'Lewis',
#   u'last_name': u'Sturges',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Taggart',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Tallmadge',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Magnus',
#   u'last_name': u'Tate',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Isaac',
#   u'last_name': u'Tichenor',
#   u'party': u'Federalist',
#   u'state': u'VT'},
#  {u'first_name': u'Roger',
#   u'last_name': u'Vose',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Artemas',
#   u'last_name': u'Ward',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Laban',
#   u'last_name': u'Wheaton',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Jeduthun',
#   u'last_name': u'Wilcox',
#   u'party': u'Federalist',
#   u'state': u'NH'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Williams',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'John',
#   u'last_name': u'Woods',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Eli',
#   u'last_name': u'Ashmun',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Alexander',
#   u'last_name': u'Hanson',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Martin',
#   u'last_name': u'Hardin',
#   u'party': u'Federalist',
#   u'state': u'KY'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Harper',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'James',
#   u'last_name': u'Monroe',
#   u'party': u'Anti-Administration',
#   u'state': u'VA'},
#  {u'first_name': u'John',
#   u'last_name': u'Boss',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'James',
#   u'last_name': u'Burrill',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'William',
#   u'last_name': u'Claiborne',
#   u'party': u'Democratic Republican',
#   u'state': u'LA'},
#  {u'first_name': u'Edward',
#   u'last_name': u'Colston',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'John',
#   u'last_name': u'Cushman',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Isaac',
#   u'last_name': u'Darlington',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'John',
#   u'last_name': u'Herbert',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Uriel',
#   u'last_name': u'Holmes',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Hopkinson',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Ebenezer',
#   u'last_name': u'Huntington',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'James',
#   u'last_name': u'Mason',
#   u'party': u'Federalist',
#   u'state': u'RI'},
#  {u'first_name': u'Alexander',
#   u'last_name': u'McMillan',
#   u'party': u'',
#   u'state': u'NC'},
#  {u'first_name': u'David',
#   u'last_name': u'Ogden',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Orr',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Harrison',
#   u'last_name': u'Otis',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Levi',
#   u'last_name': u'Pawling',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Timothy',
#   u'last_name': u'Pitkin',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Pope',
#   u'party': u'',
#   u'state': u'IL'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Rice',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Ruggles',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Philip',
#   u'last_name': u'Schuyler',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Sherwood',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'James',
#   u'last_name': u'Stewart',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Solomon',
#   u'last_name': u'Strong',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Philip',
#   u'last_name': u'Stuart',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Terry',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'Rensselaer',
#   u'last_name': u'Westerlo',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Williams',
#   u'party': u'Federalist',
#   u'state': u'CT'},
#  {u'first_name': u'John',
#   u'last_name': u'Wilson',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Prentiss',
#   u'last_name': u'Mellen',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Adams',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'William',
#   u'last_name': u'Davidson',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Jonas',
#   u'last_name': u'Kendall',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Rufus',
#   u'last_name': u'King',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Mason',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'McCullough',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'James',
#   u'last_name': u'Pindall',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Jesse',
#   u'last_name': u'Slocumb',
#   u'party': u'Federalist',
#   u'state': u'NC'},
#  {u'first_name': u'Randall',
#   u'last_name': u'Street',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Elijah',
#   u'last_name': u'Mills',
#   u'party': u'Adams',
#   u'state': u'MA'},
#  {u'first_name': u'James',
#   u'last_name': u'Bates',
#   u'party': u'',
#   u'state': u'AR'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Bayly',
#   u'party': u'Federalist',
#   u'state': u'MD'},
#  {u'first_name': u'Lewis',
#   u'last_name': u'Bigelow',
#   u'party': u'Federalist',
#   u'state': u'MA'},
#  {u'first_name': u'Cadwallader',
#   u'last_name': u'Colden',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Dane',
#   u'party': u'Federalist',
#   u'state': u'ME'},
#  {u'first_name': u'James',
#   u'last_name': u'Duncan',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'William',
#   u'last_name': u'Findlay',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Forrest',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'John',
#   u'last_name': u'Gebhard',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Hern\xe1ndez',
#   u'party': u'',
#   u'state': u'FL'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Kirkland',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'James',
#   u'last_name': u'McSherry',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'William',
#   u'last_name': u'Milnor',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Walter',
#   u'last_name': u'Patterson',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Phillips',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Ruggles',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Solomon',
#   u'last_name': u'Sibley',
#   u'party': u'',
#   u'state': u'MI'},
#  {u'first_name': u'Micah',
#   u'last_name': u'Sterling',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Selah',
#   u'last_name': u'Tuthill',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Solomon',
#   u'last_name': u'Van Rensselaer',
#   u'party': u'Federalist',
#   u'state': u'NY'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Van Swearingen',
#   u'party': u'Federalist',
#   u'state': u'VA'},
#  {u'first_name': u'Ezekiel',
#   u'last_name': u'Whitman',
#   u'party': u'Federalist',
#   u'state': u'ME'},
#  {u'first_name': u'Ludwig',
#   u'last_name': u'Worman',
#   u'party': u'Federalist',
#   u'state': u'PA'},
#  {u'first_name': u'James',
#   u'last_name': u'Lloyd',
#   u'party': u'Adams',
#   u'state': u'MA'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Breck',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'John',
#   u'last_name': u'Brown',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Hutchins',
#   u'last_name': u'Burton',
#   u'party': u'',
#   u'state': u'NC'},
#  {u'first_name': u'John',
#   u'last_name': u'Cady',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Jacob',
#   u'last_name': u'Call',
#   u'party': u'Jackson Republican',
#   u'state': u'IN'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Call',
#   u'party': u'',
#   u'state': u'FL'},
#  {u'first_name': u'John',
#   u'last_name': u'Chandler',
#   u'party': u'Jackson',
#   u'state': u'ME'},
#  {u'first_name': u'Lot',
#   u'last_name': u'Clark',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Ela',
#   u'last_name': u'Collins',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Joshua',
#   u'last_name': u'Cushman',
#   u'party': u'',
#   u'state': u'ME'},
#  {u'first_name': u'Job',
#   u'last_name': u'Durfee',
#   u'party': u'',
#   u'state': u'RI'},
#  {u'first_name': u'Justin',
#   u'last_name': u'Dwinell',
#   u'party': u'',
#   u'state': u'NY'},
#  {u'first_name': u'Lewis',
#   u'last_name': u'Eaton',
#   u'party': u'Crawford Republican',
#   u'state': u'NY'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Eddy',
#   u'party': u'',
#   u'state': u'RI'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Edwards',
#   u'party': u'Jackson',
# ...
#  {u'first_name': u'Bates',
#   u'last_name': u'Cooke',
#   u'party': u'Anti Masonic',
#   u'state': u'NY'},
#  {u'first_name': u'Eleutheros',
#   u'last_name': u'Cooke',
#   u'party': u'Anti Jacksonian',
#   u'state': u'OH'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Cooper',
#   u'party': u'',
#   u'state': u'NJ'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Crawford',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'George',
#   u'last_name': u'Dallas',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Daniel',
#   u'party': u'Jackson',
#   u'state': u'KY'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Dayan',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Dearborn',
#   u'party': u'Anti Jacksonian',
#   u'state': u'MA'},
#  {u'first_name': u'Lewis',
#   u'last_name': u'Dewart',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Philip',
#   u'last_name': u'Doddridge',
#   u'party': u'',
#   u'state': u'VA'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Draper',
#   u'party': u'Jackson',
#   u'state': u'VA'},
#  {u'first_name': u'William',
#   u'last_name': u'Drayton',
#   u'party': u'Jackson',
#   u'state': u'SC'},
#  {u'first_name': u'Joshua',
#   u'last_name': u'Evans',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'James',
#   u'last_name': u'Findlay',
#   u'party': u'Jackson',
#   u'state': u'OH'},
#  {u'first_name': u'William',
#   u'last_name': u'Fitzgerald',
#   u'party': u'Jackson',
#   u'state': u'TN'},
#  {u'first_name': u'James',
#   u'last_name': u'Ford',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'John',
#   u'last_name': u'Forsyth',
#   u'party': u'Jackson',
#   u'state': u'GA'},
#  {u'first_name': u'Nathan',
#   u'last_name': u'Gaither',
#   u'party': u'Jackson',
#   u'state': u'KY'},
#  {u'first_name': u'John',
#   u'last_name': u'Gilmore',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'William',
#   u'last_name': u'Hall',
#   u'party': u'Jackson',
#   u'state': u'TN'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Hammons',
#   u'party': u'Jackson',
#   u'state': u'NH'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Hanna',
#   u'party': u'Anti-Jacksonian',
#   u'state': u'IN'},
#  {u'first_name': u'William',
#   u'last_name': u'Hendricks',
#   u'party': u'Adams',
#   u'state': u'IN'},
#  {u'first_name': u'Isaac',
#   u'last_name': u'Hill',
#   u'party': u'Jackson',
#   u'state': u'NH'},
#  {u'first_name': u'James',
#   u'last_name': u'Hodges',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'Michael',
#   u'last_name': u'Hoffman',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'William',
#   u'last_name': u'Hogan',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Cornelius',
#   u'last_name': u'Holland',
#   u'party': u'Jackson',
#   u'state': u'ME'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Horn',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Hughes',
#   u'party': u'',
#   u'state': u'NJ'},
#  {u'first_name': u'Jonathan',
#   u'last_name': u'Hunt',
#   u'party': u'',
#   u'state': u'VT'},
#  {u'first_name': u'Peter',
#   u'last_name': u'Ihrie',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Ralph',
#   u'last_name': u'Ingersoll',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'William',
#   u'last_name': u'Irvin',
#   u'party': u'Jackson',
#   u'state': u'OH'},
#  {u'first_name': u'Jacob',
#   u'last_name': u'Isacks',
#   u'party': u'Jackson',
#   u'state': u'TN'},
#  {u'first_name': u'Freeborn',
#   u'last_name': u'Jewett',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Johnston',
#   u'party': u'Jackson',
#   u'state': u'VA'},
#  {u'first_name': u'Josiah',
#   u'last_name': u'Johnston',
#   u'party': u'',
#   u'state': u'LA'},
#  {u'first_name': u'Elias',
#   u'last_name': u'Kane',
#   u'party': u'Jackson',
#   u'state': u'IL'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Kendall',
#   u'party': u'',
#   u'state': u'MA'},
#  {u'first_name': u'Adam',
#   u'last_name': u'King',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'John',
#   u'last_name': u'King',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Lamar',
#   u'party': u'Jackson',
#   u'state': u'GA'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Lecompte',
#   u'party': u'Jackson',
#   u'state': u'KY'},
#  {u'first_name': u'James',
#   u'last_name': u'Lent',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Rollin',
#   u'last_name': u'Mallary',
#   u'party': u'',
#   u'state': u'VT'},
#  {u'first_name': u'William',
#   u'last_name': u'Marcy',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Lewis',
#   u'last_name': u'Maxwell',
#   u'party': u'Anti Jacksonian',
#   u'state': u'VA'},
#  {u'first_name': u'Robert',
#   u'last_name': u'McCoy',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'William',
#   u'last_name': u'McCoy',
#   u'party': u'Jackson',
#   u'state': u'VA'},
#  {u'first_name': u'Stephen',
#   u'last_name': u'Miller',
#   u'party': u'Nullifier',
#   u'state': u'SC'},
#  {u'first_name': u'George',
#   u'last_name': u'Mitchell',
#   u'party': u'Jackson',
#   u'state': u'MD'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Mitchell',
#   u'party': u'Jackson',
#   u'state': u'SC'},
#  {u'first_name': u'Gabriel',
#   u'last_name': u'Moore',
#   u'party': u'Jackson',
#   u'state': u'AL'},
#  {u'first_name': u'Jeremiah',
#   u'last_name': u'Nelson',
#   u'party': u'Anti Jacksonian',
#   u'state': u'MA'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Newnan',
#   u'party': u'Jackson',
#   u'state': u'GA'},
#  {u'first_name': u'William',
#   u'last_name': u'Nuckolls',
#   u'party': u'Jackson',
#   u'state': u'SC'},
#  {u'first_name': u'Edmund',
#   u'last_name': u'Pendleton',
#   u'party': u'Anti Jacksonian',
#   u'state': u'NY'},
#  {u'first_name': u'Nathaniel',
#   u'last_name': u'Pitcher',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Potter',
#   u'party': u'Jacksonian',
#   u'state': u'NC'},
#  {u'first_name': u'William',
#   u'last_name': u'Ramsey',
#   u'party': u'Jacksonian',
#   u'state': u'PA'},
#  {u'first_name': u'James',
#   u'last_name': u'Randolph',
#   u'party': u'',
#   u'state': u'NJ'},
#  {u'first_name': u'Edward',
#   u'last_name': u'Reed',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Roane',
#   u'party': u'Jackson',
#   u'state': u'VA'},
#  {u'first_name': u'Erastus',
#   u'last_name': u'Root',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Benedict',
#   u'last_name': u'Semmes',
#   u'party': u'',
#   u'state': u'MD'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Smith',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Nathan',
#   u'last_name': u'Soule',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Isaac',
#   u'last_name': u'Southard',
#   u'party': u'Anti Jacksonian',
#   u'state': u'NJ'},
#  {u'first_name': u'William',
#   u'last_name': u'Stanbery',
#   u'party': u'Anti Jacksonian',
#   u'state': u'OH'},
#  {u'first_name': u'Philander',
#   u'last_name': u'Stephens',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Wiley',
#   u'last_name': u'Thompson',
#   u'party': u'Jackson',
#   u'state': u'GA'},
#  {u'first_name': u'Gideon',
#   u'last_name': u'Tomlinson',
#   u'party': u'Anti-Jacksonian',
#   u'state': u'CT'},
#  {u'first_name': u'Phineas',
#   u'last_name': u'Tracy',
#   u'party': u'Anti Masonic',
#   u'state': u'NY'},
#  {u'first_name': u'Gulian',
#   u'last_name': u'Verplanck',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'George',
#   u'last_name': u'Waggaman',
#   u'party': u'Anti-Jacksonian',
#   u'state': u'LA'},
#  {u'first_name': u'John',
#   u'last_name': u'Weeks',
#   u'party': u'Jackson',
#   u'state': u'NH'},
#  {u'first_name': u'Grattan',
#   u'last_name': u'Wheeler',
#   u'party': u'Anti Masonic',
#   u'state': u'NY'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Wilkin',
#   u'party': u'Anti Jacksonian',
#   u'state': u'NY'},
#  {u'first_name': u'Austin',
#   u'last_name': u'Wing',
#   u'party': u'',
#   u'state': u'MI'},
#  {u'first_name': u'John',
#   u'last_name': u'Black',
#   u'party': u'Whig',
#   u'state': u'MS'},
#  {u'first_name': u'John',
#   u'last_name': u'Adams',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Allen',
#   u'party': u'Anti Jacksonian',
#   u'state': u'VA'},
#  {u'first_name': u'Noyes',
#   u'last_name': u'Barber',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Barnitz',
#   u'party': u'Anti Masonic',
#   u'state': u'PA'},
#  {u'first_name': u'Daniel',
#   u'last_name': u'Barringer',
#   u'party': u'',
#   u'state': u'NC'},
#  {u'first_name': u'William',
#   u'last_name': u'Baylies',
#   u'party': u'Anti Jacksonian',
#   u'state': u'MA'},
#  {u'first_name': u'Martin',
#   u'last_name': u'Beaty',
#   u'party': u'Anti Jackson',
#   u'state': u'KY'},
#  {u'first_name': u'James',
#   u'last_name': u'Bell',
#   u'party': u'Anti Jacksonian',
#   u'state': u'OH'},
#  {u'first_name': u'Horace',
#   u'last_name': u'Binney',
#   u'party': u'Anti Jacksonian',
#   u'state': u'PA'},
#  {u'first_name': u'James',
#   u'last_name': u'Blair',
#   u'party': u'Jackson',
#   u'state': u'SC'},
#  {u'first_name': u'John',
#   u'last_name': u'Blair',
#   u'party': u'Jackson',
#   u'state': u'TN'},
#  {u'first_name': u'Charles',
#   u'last_name': u'Bodle',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Bouldin',
#   u'party': u'Jackson',
#   u'state': u'VA'},
#  {u'first_name': u'John',
#   u'last_name': u'Bull',
#   u'party': u'',
#   u'state': u'MO'},
#  {u'first_name': u'George',
#   u'last_name': u'Burd',
#   u'party': u'',
#   u'state': u'PA'},
#  {u'first_name': u'Tristam',
#   u'last_name': u'Burges',
#   u'party': u'Anti Jacksonian',
#   u'state': u'RI'},
#  {u'first_name': u'Harry',
#   u'last_name': u'Cage',
#   u'party': u'Jackson',
#   u'state': u'MS'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Carmichael',
#   u'party': u'Jackson',
#   u'state': u'MD'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Chilton',
#   u'party': u'Anti Jacksonian',
#   u'state': u'KY'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Chinn',
#   u'party': u'Jackson',
#   u'state': u'VA'},
#  {u'first_name': u'Augustin',
#   u'last_name': u'Clayton',
#   u'party': u'Jackson',
#   u'state': u'GA'},
#  {u'first_name': u'Richard',
#   u'last_name': u'Coulter',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'David',
#   u'last_name': u'Crockett',
#   u'party': u'Anti Jacksonian',
#   u'state': u'TN'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Davenport',
#   u'party': u'Anti-Jacksonian',
#   u'state': u'VA'},
#  {u'first_name': u'Amos',
#   u'last_name': u'Davis',
#   u'party': u'Anti Jacksonian',
#   u'state': u'KY'},
#  {u'first_name': u'Rowland',
#   u'last_name': u'Day',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Deming',
#   u'party': u'Anti Masonic',
#   u'state': u'VT'},
#  {u'first_name': u'Littleton',
#   u'last_name': u'Dennis',
#   u'party': u'Anti Jacksonian',
#   u'state': u'MD'},
#  {u'first_name': u'John',
#   u'last_name': u'Dickson',
#   u'party': u'Anti Masonic',
#   u'state': u'NY'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Duncan',
#   u'party': u'Jackson',
#   u'state': u'IL'},
#  {u'first_name': u'William',
#   u'last_name': u'Ellsworth',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'John',
#   u'last_name': u'Felder',
#   u'party': u'Nullifier',
#   u'state': u'SC'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Foot',
#   u'party': u'Anti-Jacksonian',
#   u'state': u'CT'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Foote',
#   u'party': u'Anti-Jacksonian',
#   u'state': u'CT'},
#  {u'first_name': u'John',
#   u'last_name': u'Fulton',
#   u'party': u'Jackson',
#   u'state': u'VA'},
#  {u'first_name': u'James',
#   u'last_name': u'Gholson',
#   u'party': u'Anti Jacksonian',
#   u'state': u'VA'},
#  {u'first_name': u'George',
#   u'last_name': u'Gilmer',
#   u'party': u'Jackson',
#   u'state': u'GA'},
#  {u'first_name': u'William',
#   u'last_name': u'Gordon',
#   u'party': u'Jackson',
#   u'state': u'VA'},
#  {u'first_name': u'Benjamin',
#   u'last_name': u'Gorham',
#   u'party': u'Anti Jacksonian',
#   u'state': u'MA'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Hall',
#   u'party': u'Jackson',
#   u'state': u'NC'},
#  {u'first_name': u'Nicoll',
#   u'last_name': u'Halsey',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Harper',
#   u'party': u'Jackson',
#   u'state': u'NH'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Hathaway',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'James',
#   u'last_name': u'Heath',
#   u'party': u'Jackson',
#   u'state': u'MD'},
#  {u'first_name': u'Edward',
#   u'last_name': u'Howell',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'William',
#   u'last_name': u'Inge',
#   u'party': u'Jackson',
#   u'state': u'TN'},
#  {u'first_name': u'Ebenezer',
#   u'last_name': u'Jackson',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'Noadiah',
#   u'last_name': u'Johnson',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Edward',
#   u'last_name': u'Kavanagh',
#   u'party': u'Jackson',
#   u'state': u'ME'},
#  {u'first_name': u'Joseph',
#   u'last_name': u'Kent',
#   u'party': u'Whig',
#   u'state': u'MD'},
#  {u'first_name': u'Henry',
#   u'last_name': u'King',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Cornelius',
#   u'last_name': u'Lawrence',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Humphrey',
#   u'last_name': u'Leavitt',
#   u'party': u'Jackson',
#   u'state': u'OH'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Letcher',
#   u'party': u'',
#   u'state': u'KY'},
#  {u'first_name': u'James',
#   u'last_name': u'Love',
#   u'party': u'Anti Jacksonian',
#   u'state': u'KY'},
#  {u'first_name': u'Chittenden',
#   u'last_name': u'Lyon',
#   u'party': u'Jackson',
#   u'state': u'KY'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Lytle',
#   u'party': u'Jackson',
#   u'state': u'OH'},
#  {u'first_name': u'Joel',
#   u'last_name': u'Mann',
#   u'party': u'Jackson',
#   u'state': u'PA'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Mardis',
#   u'party': u'Jackson',
#   u'state': u'AL'},
#  {u'first_name': u'Thomas',
#   u'last_name': u'Marshall',
#   u'party': u'Anti Jacksonian',
#   u'state': u'KY'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Martindale',
#   u'party': u'Anti Masonic',
#   u'state': u'NY'},
#  {u'first_name': u'Rufus',
#   u'last_name': u'McIntire',
#   u'party': u'Jackson',
#   u'state': u'ME'},
#  {u'first_name': u'Charles',
#   u'last_name': u'McVean',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Phineas',
#   u'last_name': u'Miner',
#   u'party': u'',
#   u'state': u'CT'},
#  {u'first_name': u'Henry',
#   u'last_name': u'Mitchell',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Robert',
#   u'last_name': u'Mitchell',
#   u'party': u'Jackson',
#   u'state': u'OH'},
#  {u'first_name': u'Samuel',
#   u'last_name': u'Moore',
#   u'party': u'Anti Jacksonian',
#   u'state': u'VA'},
#  {u'first_name': u'John',
#   u'last_name': u'Morgan',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'John',
#   u'last_name': u'Murphy',
#   u'party': u'Jackson',
#   u'state': u'AL'},
#  {u'first_name': u'Arnold',
#   u'last_name': u'Naudain',
#   u'party': u'',
#   u'state': u'DE'},
#  {u'first_name': u'Gayton',
#   u'last_name': u'Osgood',
#   u'party': u'Jackson',
#   u'state': u'MA'},
#  {u'first_name': u'Job',
#   u'last_name': u'Pierson',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Franklin',
#   u'last_name': u'Plummer',
#   u'party': u'Jackson',
#   u'state': u'MS'},
#  {u'first_name': u'Patrick',
#   u'last_name': u'Pope',
#   u'party': u'Jackson',
#   u'state': u'KY'},
#  {u'first_name': u'Alexander',
#   u'last_name': u'Porter',
#   u'party': u'Anti-Jacksonian',
#   u'state': u'LA'},
#  {u'first_name': u'John',
#   u'last_name': u'Randolph',
#   u'party': u'',
#   u'state': u'VA'},
#  {u'first_name': u'Asher',
#   u'last_name': u'Robbins',
#   u'party': u'Whig',
#   u'state': u'RI'},
#  {u'first_name': u'Dudley',
#   u'last_name': u'Selden',
#   u'party': u'Jackson',
#   u'state': u'NY'},
#  {u'first_name': u'Ether',
#   u'last_name': u'Shepley',
#   u'party': u'Jackson',
#   u'state': u'ME'},
#  ...]

# %% [markdown]
# ## Where to go next
#
# Great work--you've learned the basics. Where to go next?
#
# * The [PyMongo tutorial](http://api.mongodb.org/python/current/tutorial.html) covers a lot of the same material that we've covered here, but it's always nice to have a different perspective on this.
# * If you want to be able to modify your data after you've imported it, you may want to learn how to [update documents](http://docs.mongodb.org/manual/tutorial/modify-documents/) once they're already in the database.
# * Once you're working with a sufficiently large amount of data, you'll be able to speed up your queries significantly using [indexes](http://docs.mongodb.org/manual/core/indexes-introduction/).
# * We didn't cover some of MongoDB's most powerful features in this tutorial, including its [aggregation](http://docs.mongodb.org/manual/core/aggregation-introduction/) and [map-reduce](http://docs.mongodb.org/manual/core/map-reduce/) features. Both are very handy, but difficult to teach in a Python class, because they often require writing JavaScript. [Here's a good overview](http://blog.safaribooksonline.com/2013/06/21/aggregation-in-mongodb/) of MongoDB's aggregation framework.
